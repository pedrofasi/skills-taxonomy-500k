# %%
### ----- GERAÇÃO/CARREGAMENTO DO CLASSIFICADOR (futuras iterações) ----- ###

from transformers import BertTokenizer, BertForSequenceClassification, Trainer, TrainingArguments, DataCollatorWithPadding
from datasets import Dataset, DatasetDict
import torch
import os
import pandas as pd

# Caminho para salvar ou carregar o modelo
MODEL_DIR = "/kaggle/working/modelo_bert_skills/"

# === 1. Carregando os dados
df = pd.read_csv("/kaggle/input/500k-atualizados/sample_skills_atualizado_500k.csv")
df["label"] = df["label"].astype(int)

# === 2. Limpeza dos dados
df = df[df["skill_name"].notnull()]  # remove nulos
df["skill_name"] = df["skill_name"].astype(str)  # garante que tudo é string

# === 3. Divisão treino/teste
df_amostra = df.sample(frac=1, random_state=42).reset_index(drop=True)
df_treino = df_amostra.iloc[:150000]
tam = len(df)
df_teste = df_amostra.iloc[150001:tam]

# === 4. Conversão para HuggingFace Dataset
dataset = DatasetDict({
    "train": Dataset.from_pandas(df_treino),
    "test": Dataset.from_pandas(df_teste)
})

# === 5. Tokenizer
tokenizer = BertTokenizer.from_pretrained("bert-base-multilingual-cased")

# === 6. Pré-processamento
def preprocess(exemplos):
    return tokenizer(
        exemplos["skill_name"],
        truncation=True,
        padding="max_length",
        max_length=64
    )

# Tokenizando sem remover nenhuma coluna ainda
dataset = dataset.map(preprocess, batched=True)

# Renomeando label
dataset = dataset.rename_column("label", "labels")

# Definindo colunas para o modelo, mas preservando as extras
dataset.set_format(
    type="torch",
    columns=["input_ids", "attention_mask", "labels"],
    output_all_columns=True  # <- mantém skill_id e skill_name
)


# Data collator necessário para batching correto com padding dinâmico
data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

# === 7. Carregamento ou criação do modelo
if os.path.exists(MODEL_DIR) and (
    "pytorch_model.bin" in os.listdir(MODEL_DIR) or "model.safetensors" in os.listdir(MODEL_DIR)):
    print("Carregando modelo salvo...")
    model_bert = BertForSequenceClassification.from_pretrained(MODEL_DIR)
    tokenizer = BertTokenizer.from_pretrained(MODEL_DIR)
    print("Modelo carregado...")
else:
    print("Treinando modelo BERT do zero...")

    model_bert = BertForSequenceClassification.from_pretrained(
        "bert-base-multilingual-cased", num_labels=3
    )

    # Detecta se há GPU disponível
    device = "cuda" if torch.cuda.is_available() else "cpu"
    print("Dispositivo usado:", device)

    # Aumenta o batch size para acelerar (se a memória permitir)
    args = TrainingArguments(
        output_dir=MODEL_DIR,
        num_train_epochs=4,  # diminui para teste mais rápido (pode aumentar depois)
        per_device_train_batch_size=16,  # <== Aumentado para maior eficiência
        per_device_eval_batch_size=32,
        warmup_steps=500,
        weight_decay=0.01,
        save_strategy="epoch",
        save_total_limit=1,  # só o mais recente
        logging_dir="/kaggle/working/logs",
        logging_steps=100,
        report_to=[],  # desativa W&B
        fp16=torch.cuda.is_available(),  # ativa FP16 se houver GPU com suporte
    )

    trainer = Trainer(
        model=model_bert,
        args=args,
        train_dataset=dataset["train"],
        eval_dataset=dataset["test"],
        tokenizer=tokenizer,
        data_collator=data_collator
    )

    print("Iniciando treinamento...")
    trainer.train()
    print("Treinamento finalizado.")

    model_bert.save_pretrained(MODEL_DIR)
    tokenizer.save_pretrained(MODEL_DIR)
    print("Modelo salvo em:", MODEL_DIR)
# Out:
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]
# Map:   0%|          | 0/150000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2264 [00:00<?, ? examples/s]
# Carregando modelo salvo...
# Modelo carregado...

# %%
# !du -sh /kaggle/working/*
# Out:
# 36K	/kaggle/working/clusters_nivel0.joblib
# 992K	/kaggle/working/clusters_nivel_max0.joblib
# 428K	/kaggle/working/hdbscan_nivel0.pkl
# 13M	/kaggle/working/hdbscan_nivel_max0.pkl
# 2.7G	/kaggle/working/modelo_bert_skills
# 84K	/kaggle/working/reduzido_nivel0.joblib
# 2.5M	/kaggle/working/reduzido_nivel_max0.joblib
# 4.0K	/kaggle/working/state.db
# 27M	/kaggle/working/umap_nivel0.pkl
# 813M	/kaggle/working/umap_nivel_max0.pkl
# 186M	/kaggle/working/vetores_embeddings.npy
# 1.3M	/kaggle/working/visualizacao1_clusters.json
# 23M	/kaggle/working/visualizacao_clusters_aux.json
# 23M	/kaggle/working/visualizacao_clusters_final.json
# 1.3M	/kaggle/working/visualizacao_clusters.json

# %%
### ----- GERAÇÃO DOS VETORES DE EMBEDDINGS ----- ###

import numpy as np
import pandas as pd
import torch
from transformers import AutoTokenizer, AutoModel

# 1. Carregar base
caminho_csv = "/kaggle/input/500k-atualizados/sample_skills_atualizado_500k.csv"
df = pd.read_csv(caminho_csv)

skills_descricao = []
skills_info = []

# Armazenar apenas as skills (removendo lixo)
for i in range(0,tam,1):
    skill_original = df.iloc[i+1, 1]
    if df.iloc[i+1, 2] != 2:
        skills_descricao.append(skill_original)
        skills_info.append(df.iloc[i+1, 2])

# 2. Embeddings (carregando modelo)
modelo_nome = "sentence-transformers/all-MiniLM-L6-v2"
tokenizer = AutoTokenizer.from_pretrained(modelo_nome)
modelo = AutoModel.from_pretrained(modelo_nome)

def gerar_embeddings(sentencas):
    entradas = tokenizer(sentencas, padding=True, truncation=True, return_tensors="pt")
    with torch.no_grad():
        saida = modelo(**entradas)
    return torch.mean(saida.last_hidden_state, dim=1).cpu().numpy()

# 3. Processamento em batches
tamanho_batch = 512  
embeddings_lista = []

for inicio in range(0, len(skills_descricao), tamanho_batch):
    fim = min(inicio + tamanho_batch, len(skills_descricao))
    batch = skills_descricao[inicio:fim]
    vetores_batch = gerar_embeddings(batch)
    embeddings_lista.append(vetores_batch)
    print(f'Processado: {fim}/{len(skills_descricao)}')

# Junta tudo em um só array
vetores_embeddings = np.vstack(embeddings_lista)

# Salva
np.save('/kaggle/working/vetores_embeddings.npy', vetores_embeddings)
# Out:
# Processado: 512/126914
# Processado: 1024/126914
# Processado: 1536/126914
# Processado: 2048/126914
# Processado: 2560/126914
# Processado: 3072/126914
# Processado: 3584/126914
# Processado: 4096/126914
# Processado: 4608/126914
# Processado: 5120/126914
# Processado: 5632/126914
# Processado: 6144/126914
# Processado: 6656/126914
# Processado: 7168/126914
# Processado: 7680/126914
# Processado: 8192/126914
# Processado: 8704/126914
# Processado: 9216/126914
# Processado: 9728/126914
# Processado: 10240/126914
# Processado: 10752/126914
# Processado: 11264/126914
# Processado: 11776/126914
# Processado: 12288/126914
# Processado: 12800/126914
# Processado: 13312/126914
# Processado: 13824/126914
# Processado: 14336/126914
# Processado: 14848/126914
# Processado: 15360/126914
# Processado: 15872/126914
# Processado: 16384/126914
# Processado: 16896/126914
# Processado: 17408/126914
# Processado: 17920/126914
# Processado: 18432/126914
# Processado: 18944/126914
# Processado: 19456/126914
# Processado: 19968/126914
# Processado: 20480/126914
# Processado: 20992/126914
# Processado: 21504/126914
# Processado: 22016/126914
# Processado: 22528/126914
# Processado: 23040/126914
# Processado: 23552/126914
# Processado: 24064/126914
# Processado: 24576/126914
# Processado: 25088/126914
# Processado: 25600/126914
# Processado: 26112/126914
# Processado: 26624/126914
# Processado: 27136/126914
# Processado: 27648/126914
# Processado: 28160/126914
# Processado: 28672/126914
# Processado: 29184/126914
# Processado: 29696/126914
# Processado: 30208/126914
# Processado: 30720/126914
# Processado: 31232/126914
# Processado: 31744/126914
# Processado: 32256/126914
# Processado: 32768/126914
# Processado: 33280/126914
# Processado: 33792/126914
# Processado: 34304/126914
# Processado: 34816/126914
# Processado: 35328/126914
# Processado: 35840/126914
# Processado: 36352/126914
# Processado: 36864/126914
# Processado: 37376/126914
# Processado: 37888/126914
# Processado: 38400/126914
# Processado: 38912/126914
# Processado: 39424/126914
# Processado: 39936/126914
# Processado: 40448/126914
# Processado: 40960/126914
# Processado: 41472/126914
# Processado: 41984/126914
# Processado: 42496/126914
# Processado: 43008/126914
# Processado: 43520/126914
# Processado: 44032/126914
# Processado: 44544/126914
# Processado: 45056/126914
# Processado: 45568/126914
# Processado: 46080/126914
# Processado: 46592/126914
# Processado: 47104/126914
# Processado: 47616/126914
# Processado: 48128/126914
# Processado: 48640/126914
# Processado: 49152/126914
# Processado: 49664/126914
# Processado: 50176/126914
# Processado: 50688/126914
# Processado: 51200/126914
# Processado: 51712/126914
# Processado: 52224/126914
# Processado: 52736/126914
# Processado: 53248/126914
# Processado: 53760/126914
# Processado: 54272/126914
# Processado: 54784/126914
# Processado: 55296/126914
# Processado: 55808/126914
# Processado: 56320/126914
# Processado: 56832/126914
# Processado: 57344/126914
# Processado: 57856/126914
# Processado: 58368/126914
# Processado: 58880/126914
# Processado: 59392/126914
# Processado: 59904/126914
# Processado: 60416/126914
# Processado: 60928/126914
# Processado: 61440/126914
# Processado: 61952/126914
# Processado: 62464/126914
# Processado: 62976/126914
# Processado: 63488/126914
# Processado: 64000/126914
# Processado: 64512/126914
# Processado: 65024/126914
# Processado: 65536/126914
# Processado: 66048/126914
# Processado: 66560/126914
# Processado: 67072/126914
# Processado: 67584/126914
# Processado: 68096/126914
# Processado: 68608/126914
# Processado: 69120/126914
# Processado: 69632/126914
# Processado: 70144/126914
# Processado: 70656/126914
# Processado: 71168/126914
# Processado: 71680/126914
# Processado: 72192/126914
# Processado: 72704/126914
# Processado: 73216/126914
# Processado: 73728/126914
# Processado: 74240/126914
# Processado: 74752/126914
# Processado: 75264/126914
# Processado: 75776/126914
# Processado: 76288/126914
# Processado: 76800/126914
# Processado: 77312/126914
# Processado: 77824/126914
# Processado: 78336/126914
# Processado: 78848/126914
# Processado: 79360/126914
# Processado: 79872/126914
# Processado: 80384/126914
# Processado: 80896/126914
# Processado: 81408/126914
# Processado: 81920/126914
# Processado: 82432/126914
# Processado: 82944/126914
# Processado: 83456/126914
# Processado: 83968/126914
# Processado: 84480/126914
# Processado: 84992/126914
# Processado: 85504/126914
# Processado: 86016/126914
# Processado: 86528/126914
# Processado: 87040/126914
# Processado: 87552/126914
# Processado: 88064/126914
# Processado: 88576/126914
# Processado: 89088/126914
# Processado: 89600/126914
# Processado: 90112/126914
# Processado: 90624/126914
# Processado: 91136/126914
# Processado: 91648/126914
# Processado: 92160/126914
# Processado: 92672/126914
# Processado: 93184/126914
# Processado: 93696/126914
# Processado: 94208/126914
# Processado: 94720/126914
# Processado: 95232/126914
# Processado: 95744/126914
# Processado: 96256/126914
# Processado: 96768/126914
# Processado: 97280/126914
# Processado: 97792/126914
# Processado: 98304/126914
# Processado: 98816/126914
# Processado: 99328/126914
# Processado: 99840/126914
# Processado: 100352/126914
# Processado: 100864/126914
# Processado: 101376/126914
# Processado: 101888/126914
# Processado: 102400/126914
# Processado: 102912/126914
# Processado: 103424/126914
# Processado: 103936/126914
# Processado: 104448/126914
# Processado: 104960/126914
# Processado: 105472/126914
# Processado: 105984/126914
# Processado: 106496/126914
# Processado: 107008/126914
# Processado: 107520/126914
# Processado: 108032/126914
# Processado: 108544/126914
# Processado: 109056/126914
# Processado: 109568/126914
# Processado: 110080/126914
# Processado: 110592/126914
# Processado: 111104/126914
# Processado: 111616/126914
# Processado: 112128/126914
# Processado: 112640/126914
# Processado: 113152/126914
# Processado: 113664/126914
# Processado: 114176/126914
# Processado: 114688/126914
# Processado: 115200/126914
# Processado: 115712/126914
# Processado: 116224/126914
# Processado: 116736/126914
# Processado: 117248/126914
# Processado: 117760/126914
# Processado: 118272/126914
# Processado: 118784/126914
# Processado: 119296/126914
# Processado: 119808/126914
# Processado: 120320/126914
# Processado: 120832/126914
# Processado: 121344/126914
# Processado: 121856/126914
# Processado: 122368/126914
# Processado: 122880/126914
# Processado: 123392/126914
# Processado: 123904/126914
# Processado: 124416/126914
# Processado: 124928/126914
# Processado: 125440/126914
# Processado: 125952/126914
# Processado: 126464/126914
# Processado: 126914/126914

# %%
### ---- GERAÇÃO DOS CLUSTERS NIVEL 0 (ESPECIFICO) ---- ###

import os
import joblib
import numpy as np
import pandas as pd
import umap
import hdbscan

# Defina o valor de nivel (exemplo: i = 0)
nivel = 0

# Checa se todos os arquivos necessários existem
umap_path = f"/kaggle/working/umap_nivel_max{i}.pkl"
hdbscan_path = f"/kaggle/working/hdbscan_nivel_max{i}.pkl"
reduzido_path = f"/kaggle/working/reduzido_nivel_max{i}.joblib"
clusters_path = f"/kaggle/working/clusters_nivel_max{i}.joblib"

if all(os.path.exists(path) for path in [umap_path, hdbscan_path, reduzido_path, clusters_path]):
    print("Arquivos encontrados! Carregando modelos e dados já processados...")
    umap_modelo = joblib.load(umap_path)
    modelo_cluster = joblib.load(hdbscan_path)
    reduzido = joblib.load(reduzido_path)
    clusters = joblib.load(clusters_path)
else:
    print("Arquivos não encontrados. Processando do zero...")
    # Carrega os embeddings já calculados
    vetores_embeddings = np.load('/kaggle/working/vetores_embeddings.npy')

    n_neighbors = 50          # Quantidade de vizinhos considerados pelo UMAP (valores altos deixam clusters mais globais/espalhados)
    min_dist = 1.0            # Distância mínima entre pontos no espaço reduzido do UMAP (1.0 deixa os clusters bem separados, sem aglomeração)
    min_cluster_size = 5      # Tamanho mínimo para um cluster ser considerado pelo HDBSCAN (clusters menores que isso são tratados como ruído)
    n_components = 5          # n_components = 5 para clusterização

    # Inicialização dos Modelos UMAP e HDBSCAN
    umap_modelo = umap.UMAP(
        n_neighbors=n_neighbors,
        n_components=n_components,
        min_dist=min_dist,
        metric='cosine',
        random_state=42
    )

    reduzido = umap_modelo.fit_transform(vetores_embeddings)

    modelo_cluster = hdbscan.HDBSCAN(
        min_cluster_size=min_cluster_size,
        min_samples=2,
        metric='euclidean'
    )

    clusters = modelo_cluster.fit_predict(reduzido)

    # Salva os modelos em arquivo
    joblib.dump(umap_modelo, umap_path)
    joblib.dump(modelo_cluster, hdbscan_path)
    joblib.dump(reduzido, reduzido_path)
    joblib.dump(clusters, clusters_path)

# Continue normalmente a partir daqui...
df_final = pd.DataFrame({"skill": skills_descricao})
df_final["x"] = reduzido[:, 0]
df_final["y"] = reduzido[:, 1]
df_final[f"cluster_n0"] = clusters

# Nomeação com GROQ LLaMA3
nomes = {}
cont = 0
for c in sorted(np.unique(clusters)):
    if c == -1:
        nomes[c] = "Ruído"
        continue
    amostras = df_final[df_final[f"cluster_n0"] == c]["skill"].tolist()[:13]
    nomes[c] = nomear_cluster(amostras, nivel)
    cont += 1
    print(f"{cont}/{len(np.unique(clusters))}")
    if(cont == 100):
        df_final[f"nome_n0"] = df_final[f"cluster_n0"].map(nomes)
        # Junção
        df_json_aux = df_final.to_dict(orient="records")
        with open("/kaggle/working/visualizacao_clusters_aux.json", "w", encoding="utf-8") as f:
            json.dump(df_json_aux, f, ensure_ascii=False, indent=2)
                

df_final[f"nome_n0"] = df_final[f"cluster_n0"].map(nomes)

print("Clusterização Nivel 0 Concluída")

# %%
print(nomes)
# Out:
# {-1: 'Ruído', 0: 'Excelência em processamento de dados.', 1: 'Domínio Pacote Office', 2: 'Domínio extenso Pacote Office.', 3: 'Excel Expertise Data Analysis Mastery', 4: 'Domínio Pacote Office Multifacetado.', 5: 'Domínio Pacote Office Amplo.', 6: 'Excelência em processamento de dados.', 7: 'Excelência em Processamento de Dados.', 8: 'Organização estrutural dados.', 9: 'Organiza categoriza classifica estrutura', 10: 'Trabalho em equipe colaborativo eficaz.', 11: 'Excelência em processamento de dados.', 12: 'Excelência em processamento de dados.', 13: 'Pacote Office Domínio Profundo', 14: 'Excelência em processamento de dados.', 15: 'Excelência em Processamento de Dados.', 16: 'Organização estruturada dados classificação.', 17: 'Organização estrutural dados classificacão.', 18: 'Organização estrutural dados complexos.', 19: 'Organiza categoriza classifica estruturas dados.', 20: 'Organização estrutural dados classificados.', 21: 'Domínio pacote Office', 22: 'Organização estrutural dados complexos.', 23: 'Negociação Habilidades Estratégicas.', 24: 'Domínio pacote Office.', 25: 'Empatia profunda compreensão humana.', 26: 'Domínio Pacote Office Aplicações .', 27: 'Pacote Office Dominio  Profissional.', 28: 'Excelência em processamento de dados.', 29: 'Excelência em processamento de dados.', 30: 'Comunicação eficiente linguagem domínio.', 31: 'Comunicação eficiente  expertise linguagem.', 32: 'Negociação estratégica comunicação.', 33: 'de Negociação Eficazes.', 34: 'Comunicacao eficiente e estratégica.', 35: 'Comunicação eficiente linguagem complexa.', 36: 'Pacote Office Domínio Completo', 37: 'Domínio Pacote Office', 38: 'Organiza e estrutura informação.', 39: 'Organização estrutural dados complexos.', 40: 'Organização estrutural dados complexos.', 41: 'Organiza informações hierarquicamente.', 42: 'Organização estruturada dados hierárquica.', 43: 'Resolução de Problemas Linguagem Complexa.', 44: 'Domínio Pacote Office  produtividade  eficiente  organ', 45: 'Domínio Pacote Office Versátil.', 46: 'Organização estrutural dados complexos.', 47: 'Organização estrutural dados complexos.', 48: 'Negociação Habilidades Comunicação Eficaz', 49: 'Concentracao Linguagem Taxonomia Dominio', 50: 'Concentração Habilidades  Taxonomia  Especialista.', 51: 'Concentração foco precisão  classificação.', 52: 'Concentração profunda análise dados.', 53: 'Negociação  Dominância  Comunicação Estratég', 54: 'Negociativas Avançadas', 55: 'Negociação Expertise Comunicação Estratégica', 56: 'Comunicação clara concisa eficaz.', 57: 'Excelência em Análise de Dados.', 58: 'Negociação Habilidades Avançadas', 59: 'Domínio Negociação Estratégica.', 60: 'Flexibilidade Adaptabilidade Processamento Linguagem.', 61: 'Flexibilidade adapta se ajusta molda transforma.', 62: 'Resolução de problemas expertise domínio.', 63: 'Problemas complexos análise lógica.', 64: 'Experiência Negociadora Estratégica.', 65: 'Negociação Expertise Comunicação Estratégica', 66: 'Excelência em processamento de dados.', 67: 'Excelência em Modelagem de Dados.', 68: 'Excel domínio especialistas dados.', 69: 'Excelência em manipulação de dados.', 70: 'Excelência em processamento de dados.', 71: 'Excelência em processamento de dados.', 72: 'Flexibilidade adaptabilidade  processamento linguagem.', 73: 'Flexível adapta se ajusta.', 74: 'Proativo solucionador problemas', 75: 'Negociação Estratégias Dominância.', 76: 'Especialista Negociação', 77: 'de Negociação Eficazes.', 78: 'Negociação Estratégica Domínio Habilidades.', 79: 'Atención a detalhes  Organização  Classificação Taxonomia', 80: 'Proatividade impulsiona organização estruturação.', 81: 'Proatividade impulsiona resultados.', 82: 'Empatia profunda compreensão humana.', 83: 'Equipe colaboração organização estrutura.', 84: 'Colaboração eficaz em equipe', 85: 'Flexibilidade adaptável diversas categorias.', 86: 'Flexibilidade adaptacao categorizacao classificacao', 87: 'Trabalho em equipe colaborativo essencial.', 88: 'Trabalho em equipe colabor ...

# %%
clusters_unicos = sorted(np.unique(clusters))
inicio_iteracao = 4124
cont = inicio_iteracao - 1  # já passou essas iterações
for c in clusters_unicos[inicio_iteracao - 1:]:
    if c == -1:
        nomes[c] = "Ruído"
        continue
    
    amostras = df_final[df_final[f"cluster_n0"] == c]["skill"].tolist()[:13]
    nomes[c] = nomear_cluster(amostras, nivel)
    
    cont += 1
    print(f"{cont}/{len(clusters_unicos)}")
    
    if cont % 100 == 0:
        df_final[f"nome_n0"] = df_final[f"cluster_n0"].map(nomes)
        df_json_aux = df_final.to_dict(orient="records")
        with open("/kaggle/working/visualizacao_clusters_aux.json", "w", encoding="utf-8") as f:
            json.dump(df_json_aux, f, ensure_ascii=False, indent=2)

# Salvar resultado final
df_final[f"nome_n0"] = df_final[f"cluster_n0"].map(nomes)
df_json_final = df_final.to_dict(orient="records")
with open("/kaggle/working/visualizacao_clusters_final.json", "w", encoding="utf-8") as f:
    json.dump(df_json_final, f, ensure_ascii=False, indent=2)

print("Clusterização Nível 0 Concluída a partir da iteração", inicio_iteracao)
# Out:
# Gestão Redes Sociais Profissional
# 4124/5588
# Análise Técnica Comunicação
# 4125/5588
# Redes Sociais Profissionalmente Dominadas
# 4126/5588
# Redes Conhecimento Técnico Avanç
# 4127/5588
# Habilidades Sociais Comunicativas
# 4128/5588
# Habilidades de Classificação Avançadas
# 4129/5588
# Conhecimento Informática Intermediário Geral
# 4130/5588
# Desenvolvimento Profissional Online
# 4131/5588
# Colaboração Eficiência Qualidade Equipe
# 4132/5588
# Informática Técnica Comunicação Efetiva
# 4133/5588
# Redes Configuração Gerenciamento Avançado
# 4134/5588
# Gestão Redes Sociais
# 4135/5588
# Análise Desenvolvimento Software
# 4136/5588
# Redes Administracao Ferramentas Sociais
# 4137/5588
# Gestão Redes Sociais Avançadas
# 4138/5588
# Gestão Informação Comunicação Saúde
# 4139/5588
# Análise Dados Software Especializados
# 4140/5588
# Visão Integrada Processos Aprendizagem
# 4141/5588
# Segurança Higiene Técnicas Avançadas
# 4142/5588
# Trabalho Autônomo Proativo Eficaz
# 4143/5588
# Redes Computadores Protocolos Segurança.
# 4144/5588
# Trabalho Independente Proativo Colaborativo
# 4145/5588
# Trabalho Equipe Independente Proativo
# 4146/5588
# Redes TCP IP Avançados
# 4147/5588
# Redes TCP IP Avançadas
# 4148/5588
# Flexível Proativa Responsável Compromissada
# 4149/5588
# Comunicação Pública Relacionamento Eficaz
# 4150/5588
# Gestão de Projetos Técnicos
# 4151/5588
# Técnicas Avançadas Banco Dados
# 4152/5588
# Informática Computadores Ferramentas Básicas
# 4153/5588
# Solidariedade Vigor Detalhes Respeito
# 4154/5588
# Design Gráfico Computacional
# 4155/5588
# Habilidades Públicas Comunicativas Eficazes
# 4156/5588
# Comunicação Eficaz Pública Fácil
# 4157/5588
# Negociação Estratégia Comercial
# 4158/5588
# Informática Hardware Software Sistemas
# 4159/5588
# Técnicas de Otimismo Avançado
# 4160/5588
# Comunicação Eficaz Com Clientes
# 4161/5588
# Manutenção Computadores Eletrônicos
# 4162/5588
# Comunicação Pública Efetiva
# 4163/5588
# Informática Técnica e Linguagem
# 4164/5588
# Instalacao Configuracao Sistemas Tecnologia
# 4165/5588
# Atendimento Publico Elevado Excelência
# 4166/5588
# Tecnologia Informação Software Avançado
# 4167/5588
# Comunicação Eficaz Equipe
# 4168/5588
# Ferramentas Linguagem Direto Talk
# 4169/5588
# Informática Básica Técnicas
# 4170/5588
# Análise Dados Linguagem Natural
# 4171/5588
# Análise Dados Linguísticos
# 4172/5588
# Manutenção Hardware Computadores
# 4173/5588
# Processamento Linguagem Swift
# 4174/5588
# Análise Dados Linguagem Natural
# 4175/5588
# Desenvolvimento Tecnologias Computacionais Avanç
# 4176/5588
# Gerenciamento de Sistemas Avançados
# 4177/5588
# Comunicacao Eficaz com Clientes
# 4178/5588
# Habilidades Comunicacao Equipe
# 4179/5588
# Análise Estratégica Liderança Inovação
# 4180/5588
# Suporte Administrativo Basico Tecnico
# 4181/5588
# Automação DevOps Ferramentas Avançadas
# 4182/5588
# Habilidades em Vários Campos
# 4183/5588
# Informática Manutenção Computadores Sistemas
# 4184/5588
# Comunicacao Trabalho Equipe Eficaz
# 4185/5588
# Desenho Técnico Avançado
# 4186/5588
# Conhecimento Jurídico Avançado
# 4187/5588
# Habilidades Sociais Equipe Trabalho
# 4188/5588
# Trabalho Equipe Comunicacao Eficacia
# 4189/5588
# Hardware Desenvolvimento Firmware Expertise
# 4190/5588
# Manutencao Hardware Software
# 4191/5588
# Técnicas Especializadas em Legislação
# 4192/5588
# Técnicas Desenho Mecânico Avanç
# 4193/5588
# Habilidades Esportivas Coletivas
# 4194/5588
# Dialogo Matematico Comercio
# 4195/5588
# Gestão Comunicação Equipe Efetiva
# 4196/5588
# Habilidades Avançadas Time
# 4197/5588
# Adaptação Equipe Trabalho Foco
# 4198/5588
# Logistica Distribuição Conhecimento Experiencia
# 4199/5588
# Comunicação Empática Liderança Segurança
# 4200/5588
# Logistica Avançada e Operacional
# 4201/5588
# Nutricao Idosa Moeda Humilde
# 4202/5588
# Design Grafico Sistema
# 4203/5588
# Análise Dados Ciência Computação
# 4204/5588
# Logística Gestão Coordenação Técnica
# 4205/5588
# Planejamento Montagem Manutenção Logística
# 4206/5588
# Comunicação Eficaz Pública Profissional
# 4207/5588
# Análise Desempenho Humano Tecnológico
# 4208/5588
# Análise Dados Geoespaciais
# 4209/5588
# Técnicas Avançadas Operacionais
# 4210/5588
# Rapidez Aprendizado Comunicacao Pontual
# 4211/5588
# Tecnologias Móveis Servidores Segurança
# 4212/5588
# Gestão Logística de Suprimentos
# 4213/5588
# Gestao Logistica Expedicao Formacao
# 4214/5588
# Projeto Eletrico Hidraulico Suporte
# 4215/5588
# Informática Básica Atendimento Farmácia
# 4216/5588
# Suporte Técnico Avançado
# 4217/5588
# Informática Matemática Análise Técnicas
# 4218/5588
# Conhecimento Avançado Informática
# 4219/5588
# Vendas Tecnologia Gestão Informação
# 4220/5588
# Operações Minerais Legislação
# 4221/5588
# Desenvolvimento Software Liderança Tecnologia
# 4222/5588
# Gestão Desenvolvimento Software
# 4223/5588
# Gestão Processos Desenho Business
# 4224/5588
# Meteorologia Técnicas Avançadas
# 4225/5588
# Comunicacao Cliente Satisfacao Empatia
# 4226/5588
# Gestão CRM Atendimento Cliente
# 4227/5588
# Tecnologias Integracao Gestao Sistemas
# 4228/5588
# Gestão Relacional Cliente Master
# 4229/5588
# Trabalho Equipe Comunicação Habilidades
# 4230/5588
# Comunicação Eficaz com Público
# 4231/5588
# Comunicacao Gestao Estrategica
# 4232/5588
# Análise Processamento Informações Técnicas
# 4233/5588
# Gestão Relacionamento Equipe
# 4234/5588
# Análise Software Geoespaciais
# 4235/5588
# Herramientas Geoespaciales Análisis
# 4236/5588
# Controle Gestão Análise Eficiência
# 4237/5588
# Desenvolvimento Microserviços Software Avançado
# 4238/5588
# Geoprocessamento Ferramentas SIG
# 4239/5588
# Análise Dados Informática Comunicação
# 4240/5588
# Habilidades Proativas de Trabalho
# 4241/5588
# Atenção Foco Energia Dinâmico
# 4242/5588
# Habilidades de Análise Rápida
# 4243/5588
# Atendimento Público Eficaz
# 4244/5588
# Análise Comunicação Desenvolvimento Profissional
# 4245/5588
# Habilidades Proativas de Sucesso
# 4246/5588
# Habilidades Proativas Elevadas
# 4247/5588
# Aprendizado Dinâmico Fácil Ação
# 4248/5588
# Trabalho Remoto Analise Equipe
# 4249/5588
# Sistemas Gerenciamento Produtividade Avan
# 4250/5588
# Segurança Informação Avançada Técnicas.
# 4251/5588
# Trabalho Equipe Colaboração Efetiva
# 4252/5588
# Habilidades Gerais de Comunicação
# 4253/5588
# Conhecimentos Informatica Básicos
# 4254/5588
# Análise Financeira Avançada
# 4255/5588
# Negociação Vendas Comercialização Estratégia
# 4256/5588
# Operacoes Caixa Manutencao Servicos
# 4257/5588
# Habilidades Comunicacao Publico Efetiva
# 4258/5588
# Comunicação Eficaz em Grupo
# 4259/5588
# Gestão Eficiente Controle Ponto
# 4260/5588
# Mecânica Especializada Segurança Atendimento.
# 4261/5588
# Informática Básica Avançada
# 4262/5588
# Habilidades Públicas Eloquência
# 4263/5588
# Segurança Alimentar Maquina Fusao
# 4264/5588
# Habilidades Públicas Avançadas
# 4265/5588
# Habilidades Públicas Fala Comunicativa
# 4266/5588
# Gestao Controle Qualidade Operacional
# 4267/5588
# Controle Gestao Qualidade Seguranca
# 4268/5588
# Sistemas Informação Tecnologia Estratégia
# 4269/5588
# Trabalho Segurança Clientes
# 4270/5588
# Adaptação Equipe Liderança Criatividade
# 4271/5588
# Trabalho Equipe Aprendizado Rápido
# 4272/5588
# Inspecao Otimizacao Controle Processos
# 4273/5588
# Segurança Prevenção Conservação Análise
# 4274/5588
# Habilidades Fala Pública Avançadas
# 4275/5588
# Habilidades Fala Pública Avançadas
# 4276/5588
# Manutenção Técnica Culinária
# 4277/5588
# Segurança Informação Conhecimento Fundamentos
# 4278/5588
# Atendimento ao Publico Excelente
# 4279/5588
# Trabalho Equipe Colaboração Eficaz
# 4280/5588
# Comunicação Pública Eficazmente
# 4281/5588
# Atendimento Comunicação Público Efetivo
# 4282/5588
# Desenvolvimento Humano Grupo
# 4283/5588
# Segurança Informação Sistemas Gestão
# 4284/5588
# Acolhimento Humano Comportamento Desenvolvimento
# 4285/5588
# Atendimento Empático Humanizado Integral
# 4286/5588
# Liderança Energia Aprendizado Contínuo
# 4287/5588
# Comunicação Pública Eficaz
# 4288/5588
# Comunicacao Pública Efetiva
# 4289/5588
# Segurança Veículos Grandes Legislação
# 4290/5588
# Técnicas Operação Conhecimento Especializado
# 4291/5588
# Manutenção Fornecedores Desenvolvimento Produtivo
# 4292/5588
# Gestão Eficiente Delegação Tarefas.
# 4293/5588
# Habilidades Técnicas Avançadas
# 4294/5588
# Análise Desempenho Diário
# 4295/5588
# Habilidades Interpessoais Avançadas
# 4296/5588
# Habilidades Técnicas de Campo
# 4297/5588
# Controle Gestão Monitoramento Análise
# 4298/5588
# Gestão de Projetos Eficiente
# 4299/5588
# Análise Dados Inteligência Artificial
# 4300/5588
# Prazos Detalhamento Conteudo Paciente
# 4301/5588
# Habilidades Comunicação Efetiva
# 4302/5588
# Conhecimento Básico Informática Geral
# 4303/5588
# Design Grafico Edicao Avancada
# 4304/5588
# Direção Matemática Operação Segurança
# 4305/5588
# Defesa Estratégia Tática
# 4306/5588
# Ferramentas Criativas Marketing Digital
# 4307/5588
# Gerenciamento Contas Avançado
# 4308/5588
# Análise Processamento Linguagem Avançada
# 4309/5588
# Trabalho Equipe Colaboração Análise
# 4310/5588
# Trabalho Equipe Proativo Aprendizado
# 4311/5588
# Controle Qualidade Processos Técnicos
# 4312/5588
# Evolução Segurança Aprendizado Ajuda
# 4313/5588
# Informática Ferramentas Online
# 4314/5588
# Sistemas Informática Avançada
# 4315/5588
# Sistemas Gestão Empresa Totvs
# 4316/5588
# Disposição Aprender Relacionar Pessoas
# 4317/5588
# Técnicas Organizacionais Gestão Processos
# 4318/5588
# Habilidades Coordenacao Linguagem
# 4319/5588
# Atendimento Publico Excelente
# 4320/5588
# Sistemas Informacao Tecnologia Avançada
# 4321/5588
# Habilidades de Processamento
# 4322/5588
# Controle Gestao Ativos Tecnologia
# 4323/5588
# Controle Geral de Riscos
# 4324/5588
# Gestão Ágil Liderança Comunicação
# 4325/5588
# Gestão Segurança Operacional Eficiência
# 4326/5588
# Defesa Aprendizado Operacoes Avançadas
# 4327/5588
# Informática Tecnologia Vendas Conhecimento
# 4328/5588
# Sistemas Informação Gerenciamento
# 4329/5588
# Conhecimento Informática Básica
# 4330/5588
# Desenvolvimento Web Frameworks Segurança
# 4331/5588
# Atendimento Público Profissional Eficaz
# 4332/5588
# Atendimento Publico Excelencia Comunicacao
# 4333/5588
# Tecnologia Informação Comunicação
# 4334/5588
# Conhecimentos Informática Básicas
# 4335/5588
# Tecnologia Informacao Analise
# 4336/5588
# Comunicação Eficaz Cliente Focado
# 4337/5588
# Atendimento Empático ao Cliente
# 4338/5588
# Informatica Avancada Gestao Lideranca
# 4339/5588
# Tecnologia Informacao Comunicacao
# 4340/5588
# Análise Técnicas de Seleção
# 4341/5588
# Habilidades de Comunicação Eficaz
# 4342/5588
# Análise Dados Processamento Informação.
# 4343/5588
# Técnicas de Resolução de Conflitos
# 4344/5588
# Técnicas Inspeção Organização
# 4345/5588
# Habilidades Informática Avançada
# 4346/5588
# Gestão Financeira Mercados
# 4347/5588
# Habilidades Profissionais Essenciais
# 4348/5588
# Conhecimentos Financeiros Avançados
# 4349/5588
# Análise Financeira Avançada
# 4350/5588
# Conhecimento Informática Avançado
# 4351/5588
# Organizacao Comunicacao Equipe Foco
# 4352/5588
# Gestão de Pessoas e Segurança
# 4353/5588
# Análise Financeira Avançada
# 4354/5588
# Conhecimento Informática Avançado
# 4355/5588
# Pensamento Criativo Artístico Inovador
# 4356/5588
# Informática Básica e Avançada
# 4357/5588
# Conhecimento Básico em Informática
# 4358/5588
# Vendas Atendimento Cliente B2B
# 4359/5588
# Atendimento Cliente Focado Solucoes
# 4360/5588
# Habilidades Gerais Profissionais
# 4361/5588
# Habilidades de Adaptação Avançadas
# 4362/5588
# Análise Matemática Avançada
# 4363/5588
# Especialista em Comunicação Eficaz
# 4364/5588
# Comunicacao Adaptacao Trabalho Equipe
# 4365/5588
# Gestão Segurança Compras Desenvolvimento
# 4366/5588
# Atendimento Cliente Focado Diferencial
# 4367/5588
# Análise Financeira Avançada Modelagem
# 4368/5588
# Habilidades Vendas Comunicação Efetiva
# 4369/5588
# Análise Dados Insights Profundo
# 4370/5588
# Habilidades Comunicação Eficaz
# 4371/5588
# Gestão de Processos Avançados
# 4372/5588
# Comunicação Estratégica Empática
# 4373/5588
# Flexibilidade em Ambientes Dinâmicos
# 4374/5588
# Análise Plataformas Suporte Lógica
# 4375/5588
# Adaptação Proativa Confiante
# 4376/5588
# Sistemas Gerenciamento Classificação
# 4377/5588
# Gestão de Processos Empresariais
# 4378/5588
# Relacionamento Cliente Simpatia Efetiva
# 4379/5588
# Mecânica, Manutenção, Tecnologia,
# 4380/5588
# Valuation Excellence Team Lead
# 4381/5588
# Vendas Orientação Escrita Agilidade
# 4382/5588
# Excelente Relacionamento Com Cliente
# 4383/5588
# Adaptação Flexibilidade Resiliência Evolução
# 4384/5588
# Excelente Capacidade Adaptativa Geral
# 4385/5588
# Artes Marciais Defesa Pessoal
# 4386/5588
# Atendimento Cliente Vendas Online
# 4387/5588
# Habilidades Comunicação Eficaz
# 4388/5588
# Habilidades Comunicacao Interpessoais
# 4389/5588
# Equipe Humana Comunicacao Trabalho
# 4390/5588
# Gestão Qualidade Engenharia Eletrica
# 4391/5588
# Habilidades Linguagem Escrita Avançada
# 4392/5588
# Excelente Relacionamento com Clientes
# 4393/5588
# Atendimento Cliente Experiência Total
# 4394/5588
# Comunicação Foco Competência
# 4395/5588
# Gestão Rotas Pacotes Office
# 4396/5588
# Habilidades de Atendimento ao Cliente
# 4397/5588
# Relacionamento Cliente Saúde Efetivo
# 4398/5588
# Comunicação Eficaz Relacionamento
# 4399/5588
# Comunicacao Interpessoal Eficaz
# 4400/5588
# Comunicacao Proatividade Comprometimento
# 4401/5588
# Gestão Relacionamento Cliente Fornecedor
# 4402/5588
# Gestão Relacionamento Cliente Eficaz
# 4403/5588
# Administracao Financeira Empresarial
# 4404/5588
# Gestão Relacionamento Cliente Efetivo
# 4405/5588
# Comunicação Eficaz Liderança Dinâmica
# 4406/5588
# Análise Financeira Controle Indicadores
# 4407/5588
# Relacionamento Cliente e Equipe
# 4408/5588
# Gestão Relacionamento Cliente Efetiva
# 4409/5588
# Gestão Estratégica Controle Operacional
# 4410/5588
# Planejamento Controle Gestão Eficiência
# 4411/5588
# Análise Comunicação Liderança
# 4412/5588
# Habilidades Comunicação Empática Proativa
# 4413/5588
# Análise Financeira Avançada
# 4414/5588
# Gestão Pessoas Tecnologia Informação
# 4415/5588
# Comunicação Eficaz Equipe Sucesso
# 4416/5588
# Habilidades Sociais Profissionais
# 4417/5588
# Organizacao Trabalho Equipe Comunicacao
# 4418/5588
# Análise Financeira Técnica Avanç
# 4419/5588
# Finanças Investimentos Planejamento
# 4420/5588
# Gestão Produção Ética Profissional
# 4421/5588
# Comunicação Equipe Organização
# 4422/5588
# Atendimento Proativo Inovador Estratégico
# 4423/5588
# Lideranca Comunicacao Trabalho Equipe
# 4424/5588
# Comunicação Eficaz em Equipe
# 4425/5588
# Sistema Apresentacoes Aptidao Diversas
# 4426/5588
# Gestão Sistemas Análise Técnicas
# 4427/5588
# Trabalho Equipe Organizacao Proatividade
# 4428/5588
# Trabalho Equipe Organizacao Foco
# 4429/5588
# Comunicacao Lideranca Proatividade
# 4430/5588
# Comunicacao Agilidade Profissional
# 4431/5588
# Design Gráfico Desenvolvimento Tecnológico
# 4432/5588
# Trabalho Equipe Organizacao
# 4433/5588
# Trabalho Equipe Organizada Proativa
# 4434/5588
# Design Interativo Soluções Técnicas
# 4435/5588
# Habilidades Diversas Profissionais
# 4436/5588
# Desenvolvimento Web Avançado Ferramentas
# 4437/5588
# Análise Financeira Planejamento Dados
# 4438/5588
# Atendimento Cliente Tecnologia Avançada
# 4439/5588
# Habilidades Sociais Profissionais
# 4440/5588
# Ferramentas Tecnologia Análise Dados
# 4441/5588
# Análise Financeira Estratégica Contábil
# 4442/5588
# Habilidades Sociais Elevadas
# 4443/5588
# Ilustração Avançada Habilidade Artística
# 4444/5588
# Comunicação Eficaz Relacionamento
# 4445/5588
# Comunicação Dinâmica Proativa
# 4446/5588
# Adaptação Eficaz em Ambiente
# 4447/5588
# Suporte Identificação Apresentável Power
# 4448/5588
# Habilidades Sociais Profissionais
# 4449/5588
# Aprendizado Adaptacao Proatividade
# 4450/5588
# Liderança Inovação Cultura Equipe
# 4451/5588
# Matematica Financeira Avancada
# 4452/5588
# Aprendizado Rápido Adaptabilidade Efetiva
# 4453/5588
# Adaptação Rápida Aprendizado Efic
# 4454/5588
# Atendimento Cliente Foco Sucesso
# 4455/5588
# Comunicação Relacionamento Interpessoal
# 4456/5588
# Comunicacao Eficaz em Equipe
# 4457/5588
# Técnicas de Defesa Dirigir
# 4458/5588
# Atendimento Cliente Foco Empatia
# 4459/5588
# Habilidades Gerais de Serviço
# 4460/5588
# Rapidez Aprendizado Observação Atenta
# 4461/5588
# Gestão Financeira Avançada
# 4462/5588
# Atendimento Cliente Avançado
# 4463/5588
# Habilidades Comunicacao Relacionamento Interpesso
# 4464/5588
# Habilidades Comunicacao Interpessoal
# 4465/5588
# Comunicacao Proatividade Aprendizado
# 4466/5588
# Gestão Projetos Ferramentas Produtiv
# 4467/5588
# Atendimento Cliente Experiência Qualidade
# 4468/5588
# Atendimento Cliente Qualidade Eficacia
# 4469/5588
# Rapidez Foco Aprendizado Eficaz
# 4470/5588
# Responsável Focado Comunicativo Proativo
# 4471/5588
# Desenvolvimento Pessoal Liderança Comunicação
# 4472/5588
# Atendimento Focado Cliente Satisfação
# 4473/5588
# Atendimento ao Cliente Experiente
# 4474/5588
# Comunicativa Organizada Proativa Profissional
# 4475/5588
# Habilidades Comunicacionais Avançadas
# 4476/5588
# Análise Crítica Pensamento Estratégico
# 4477/5588
# Regulamentacao Otimizacao Analise Socioambient
# 4478/5588
# Comunicação Eficaz Escrita
# 4479/5588
# Análise Financeira Controle Gestão
# 4480/5588
# Desenvolvimento Web Serviços Integrados
# 4481/5588
# Gestão Financeira Avançada
# 4482/5588
# Finanças Contabilidade Rotinas
# 4483/5588
# Finanças Controle Gestão Regulação
# 4484/5588
# Responsável Agil Proativa Efetiva
# 4485/5588
# Responsável Pontual Comunicativa
# 4486/5588
# Proativa Dinamica Dedicada Competente
# 4487/5588
# Proativa Comunicativa Responsável Dinâmica
# 4488/5588
# Habilidades Sociais Profissionais
# 4489/5588
# Habilidades Comunicacao Eficaz
# 4490/5588
# Atendimento Cliente Vendas Eficazes
# 4491/5588
# Comunicação Eficaz em Vendas
# 4492/5588
# Habilidades Linguagem Administração
# 4493/5588
# Comunicação Adaptabilidade Empatia Eficácia
# 4494/5588
# Gestão Clientes e Equipes
# 4495/5588
# Vendas Estratégicas Talentos Midias
# 4496/5588
# Plataformas Comunicação Empresa
# 4497/5588
# Atendimento Vendas Ética Cliente
# 4498/5588
# Atendimento Cliente Focado Resultados
# 4499/5588
# Gestão Soluções Corporativas
# 4500/5588
# Comunicacao Aprendizado Confianca
# 4501/5588
# Comunicação Eficaz em Ambiente
# 4502/5588
# Comunicação Eficaz Relacionamento Público
# 4503/5588
# Gestão Estratégica Logística Controle
# 4504/5588
# Finanças Análise Contabilidade
# 4505/5588
# Análise Financeira Avançada
# 4506/5588
# Comunicação Eficaz Liderança Sucesso
# 4507/5588
# Comunicação Efetiva Habilidades Profissionais
# 4508/5588
# Excelente Comunicação Escrita
# 4509/5588
# Desenvolvimento Conhecimento Técnicas
# 4510/5588
# Conhecimento Técnicas Desenvolvimento Avanç
# 4511/5588
# Conhecimento Fiscal Contabilidade
# 4512/5588
# Edição Design Gráficos Computacionais
# 4513/5588
# Segurança Qualidade Produtos
# 4514/5588
# Excelente Comunicação Escrita Eficaz
# 4515/5588
# Comunicacao Socializacao Eficaz
# 4516/5588
# Desenvolvimento Tecnologias Avançadas
# 4517/5588
# Análise Financeira Avançada
# 4518/5588
# Atendimento Cliente Eficiência Agilidade
# 4519/5588
# Atendimento Cliente Habilidades Essenciais
# 4520/5588
# Excelente Comunicação Linguagem Avançada
# 4521/5588
# Excelente Comunicação Eficaz
# 4522/5588
# Técnicas de Soldagem Avançadas
# 4523/5588
# Controle Financeiro Avançado
# 4524/5588
# Finanças Gestão Contabilidade Análise
# 4525/5588
# Gestão Financeira Avançada
# 4526/5588
# Atendimento Cliente Relacionamento Técnicas
# 4527/5588
# Vendas e Gestão de Pessoas
# 4528/5588
# Análise Financeira Calculo Nacional
# 4529/5588
# Habilidades Comunicação Eficaz Claro
# 4530/5588
# Contabilidade Direção Fiscal
# 4531/5588
# Ferramentas Tecnologia Informação Gerenciamento
# 4532/5588
# Ferramentas Avançadas Edição Imagem
# 4533/5588
# Análise Financeira Contábil Matemática
# 4534/5588
# Habilidades Comunicacao Negociacao Excelentes
# 4535/5588
# Finanças Contábil Gerenciamento
# 4536/5588
# Gestão Financeira Controle Operacional
# 4537/5588
# Gestão Financeira e Administrativa
# 4538/5588
# Finanças Gestão Estratégica
# 4539/5588
# Trabalho Equipe Análise Pessoa
# 4540/5588
# Habilidades Comunicacao Avancada Gentil
# 4541/5588
# Certificação Tecnologia Informática Avançada
# 4542/5588
# Comunicação Negociação Eficaz
# 4543/5588
# Atendimento Relacionamento Cliente Foco
# 4544/5588
# Prospecção Clientes Técnicas Avançadas
# 4545/5588
# Atendimento Cliente Avançado
# 4546/5588
# Ferramentas Desenvolvimento Geoespacial Git
# 4547/5588
# Excelente Comunicação Eficaz
# 4548/5588
# Análise Desempenho Arquitetônica
# 4549/5588
# Gestão Projetos Qualidade Desenho
# 4550/5588
# Comunicação Eficaz Foco Cliente
# 4551/5588
# Habilidades Comunicacao Colaboracao
# 4552/5588
# Comunicacao Negociacao Habilidades Excelentes
# 4553/5588
# Habilidades Comunicacao Empreendedorial
# 4554/5588
# Contabilidade Empatia Criatividade
# 4555/5588
# Liderança Dinâmica Grupo Feliz
# 4556/5588
# Compreender Necessidades Clientes Surpreender
# 4557/5588
# Habilidades Comunicacao Proativa Adaptativa
# 4558/5588
# Desenvolvimento Pessoal Profissional
# 4559/5588
# Negociação Persuasão Vendas Clientes
# 4560/5588
# Aprendizado Rápido Resultados Eficazes
# 4561/5588
# Habilidades Comunicacao Eficaz
# 4562/5588
# Técnicas de Modelagem 3D
# 4563/5588
# Comunicação Eficaz com Clientes
# 4564/5588
# Interacao Negocio Cliente Satisfacao
# 4565/5588
# Gestão Comunicação Mudanças Estratégicas
# 4566/5588
# Comunicação Eficaz em Vendas
# 4567/5588
# Comunicação Eficaz em Grupo
# 4568/5588
# Comunicação Boa Aprendizagem Proativa
# 4569/5588
# Mineração Siderurgia Engenharia Automação
# 4570/5588
# Desenvolvimento Linguagem Golang Eficaz
# 4571/5588
# Comunicação Eficaz Interna Empática
# 4572/5588
# Comunicação Eficaz e Assertiva
# 4573/5588
# Gestão Obras Planejamento Cronograma
# 4574/5588
# Técnicas Diversas Formação Profissional
# 4575/5588
# Tecnologia Comercial Conhecimento Produto
# 4576/5588
# Habilidades Técnicas Profissionais
# 4577/5588
# Comunicação Eficaz Aprendizado Rápido
# 4578/5588
# Gestão de Recursos Humanos
# 4579/5588
# Comunicação Escrita Falada Avançada
# 4580/5588
# Comunicação Eficaz em Ambientes
# 4581/5588
# Comunicação Eficaz Proativa
# 4582/5588
# Comunicacao Facil Aprendizado
# 4583/5588
# Técnicas de Persuasão Avançada
# 4584/5588
# Desenvolvimento Equipes Analise Química
# 4585/5588
# Desenvolvimento Integração Ferramentas Liderança
# 4586/5588
# Ferramentas Desenvolvimento Tecnologia Cloud
# 4587/5588
# Edição Visualização Tática Agregação
# 4588/5588
# Gestão Armazenamento Logística Administrativa
# 4589/5588
# Gestão Integrada de Projetos
# 4590/5588
# Técnicas Avançadas Ambientais
# 4591/5588
# Acolhimento Agile Skills
# 4592/5588
# Especialista Power BI Avançado
# 4593/5588
# Análise Dados Visualização
# 4594/5588
# Vendas Negociação Cliente Satisfação
# 4595/5588
# Limpeza Operações Vendas Técnicas
# 4596/5588
# Gestao Projetos Solucoes Inovadoras
# 4597/5588
# Análise Faturamento Relatórios Estratégicos
# 4598/5588
# Atendimento Venda Fidelidade Cliente
# 4599/5588
# Atendimento Clientes Excelência Negociação
# 4600/5588
# Materiais Mecatronica Metal Cultura
# 4601/5588
# Habilidades Comunicativas Profissionais
# 4602/5588
# Gestao Automacao Terapia Lideranca
# 4603/5588
# Automacao Eletrica Controle Projeto
# 4604/5588
# Habilidades Técnicas Precisas
# 4605/5588
# Desenvolvimento Químico Segurança Aplicada
# 4606/5588
# Projetos Eletricos Montagem Embalagem
# 4607/5588
# Rapidez Precisao Responsabilidade Agilidade
# 4608/5588
# Análise de Dados Especializado
# 4609/5588
# Gestão Projetos Arquitetônicos
# 4610/5588
# Desenvolvimento Integracao Ferramentas Profissionais
# 4611/5588
# Desenhos Técnicos Fiscal Arquivamento
# 4612/5588
# Gestão Qualidade Desenvolvimento Equipe
# 4613/5588
# Ferramentas Gestão Projetos Colaboração
# 4614/5588
# Ferramentas DevOps Automatização Testes
# 4615/5588
# Ferramentas Desenvolvimento Análise Dados
# 4616/5588
# Análise de Dados Empresariais
# 4617/5588
# Relatórios Qualidade Ferramentas Desenvolvimento
# 4618/5588
# Liderança Comunicação Organização
# 4619/5588
# Liderança Organização Comunicação
# 4620/5588
# Vendas Conteúdo Segurança Gestão
# 4621/5588
# Análise Requisitos Estratégicos
# 4622/5588
# Análise Gestão Indicadores Complexos
# 4623/5588
# Aprendo Rápido Sou Proativo
# 4624/5588
# Aprendizado Colaborativo Reflexivo Efetivo
# 4625/5588
# Liderança Gestão Pessoas Ideias
# 4626/5588
# Relacionamento Estratégia Aprendizado Liderança
# 4627/5588
# Acolher Criar Inovar Solucionar
# 4628/5588
# Adaptação Rápida Aprendizado Efic
# 4629/5588
# Habilidades Gerais Profissionais
# 4630/5588
# Aprendizado Comunicação Interpessoal
# 4631/5588
# Atenção Criatividade Detalhes Empatia
# 4632/5588
# Habilidades Interpessoais Profissionais
# 4633/5588
# Aprendizado Fácil Foco Rápido
# 4634/5588
# Cozinha Gestão Ferramentas Pessoas
# 4635/5588
# Metodologias Ágil Gerenciamento Projetos
# 4636/5588
# Análise Dados Visualização Tecnologia
# 4637/5588
# Desenvolvimento Plataforma Ferramentas Tecnologia
# 4638/5588
# Gestão Sistemas Eletrônicos Avanç
# 4639/5588
# Tecnologias Ferramentas Gestão Dados
# 4640/5588
# Edição Design Office Tools.
# 4641/5588
# Gestão Estratégica de Equipes
# 4642/5588
# Análise Estratégia Gestão Projetos
# 4643/5588
# Rapido Aprendizado Focado Resultado
# 4644/5588
# Gestão Estoques Tecnologias RH
# 4645/5588
# Estratégias Vendas Eletrônica Climática
# 4646/5588
# Equipamentos Manutencao Operacao Tecnicas
# 4647/5588
# Habilidades Linguísticas Avançadas
# 4648/5588
# Gestão Projetos Qualidade Desempenho
# 4649/5588
# Proativo Comunicativo Adaptável Prestativo
# 4650/5588
# Análise Dados Business Inteligência
# 4651/5588
# Contabilidade Matemática Segurança Societária
# 4652/5588
# Técnicas Diversas Saúde Computação
# 4653/5588
# Gestão Qualidade Conteúdo Vendas
# 4654/5588
# Matemática e Conceitos Avançados
# 4655/5588
# Segurança Infraestrutura Gestão Qualidade.
# 4656/5588
# Desenvolvimento Sistemas Informação Tecnológica
# 4657/5588
# Segurança Rede Computação
# 4658/5588
# Análise Técnicas Engenharia Simulação
# 4659/5588
# Sistemas Tecnologia Segurança Desenvolvimento
# 4660/5588
# Sistemas Operacionais e Backup
# 4661/5588
# Desenvolvimento Tecnologias Avançadas
# 4662/5588
# Edição Vídeo Profissional
# 4663/5588
# Desenvolvimento Cadmatic Avançado
# 4664/5588
# Desenvolvimento Profissional Diversas Habilidades
# 4665/5588
# Atenção ao Detalhe Profissional
# 4666/5588
# Gestão Processos Analise Comportamental
# 4667/5588
# Habilidades Sociais Comunicativas
# 4668/5588
# Análise Técnica Laboratório
# 4669/5588
# Ferramentas Desenvolvimento Messaging Integracao
# 4670/5588
# Segurança Dados Processamento Avançado
# 4671/5588
# Habilidades Técnicas Informática Avançada
# 4672/5588
# Aprendizado Rápido Foco Resultados
# 4673/5588
# Aprendizado Rápido Adaptável Eficaz
# 4674/5588
# Gestão Confiável Aprendizado Rápido
# 4675/5588
# Rapidez Adaptação Agilidade Pro
# 4676/5588
# Rapido Pro Ativo Organizado
# 4677/5588
# Comunicativa Proativa Rápida Eficiente
# 4678/5588
# Tecnologias Integracao Mensagem Servico
# 4679/5588
# Rapido Amigavel Aprendizado Eficaz
# 4680/5588
# Segurança Informática Sistemas
# 4681/5588
# Análise Linguística Avançada
# 4682/5588
# Análise Detalhada Rápida
# 4683/5588
# Aprendizado Rápido Foco Execução
# 4684/5588
# Análise Cloud Computing Avançada
# 4685/5588
# Gestao Produtos Juridicos Logistica
# 4686/5588
# Aprendizado Rápido e Eficiente
# 4687/5588
# Aprendo Rápido Me Adapto
# 4688/5588
# Habilidades Diversas Técnicas Físicas
# 4689/5588
# Habilidades Sociais Gerais
# 4690/5588
# Comunicação Eficaz Gestão Pessoal
# 4691/5588
# Liderança Colaboração Aprendizado Controle
# 4692/5588
# Tecnologias Análise Dados Computação
# 4693/5588
# Habilidades de Processamento
# 4694/5588
# Análise de Dados Gráficos
# 4695/5588
# Conhecimento Plataforma Vídeo Curta
# 4696/5588
# Análise Visualização Design Tecnológico
# 4697/5588
# Inteligência Artificial Mulesoft
# 4698/5588
# Gestão Dinamismo Comunicação Eficaz
# 4699/5588
# Segurança Redes Computacionais
# 4700/5588
# Ferramentas Desenvolvimento Banco Dados
# 4701/5588
# Manutenção Industrial Inovação Tecnológica
# 4702/5588
# Linguagem Processamento Natural
# 4703/5588
# Liderança Criativa Foco Resultado
# 4704/5588
# Certificacoes Regulatorias Agricolas
# 4705/5588
# Gestão Técnicas Interpessoal Desen
# 4706/5588
# Habilidades Linguagem Avançadas
# 4707/5588
# Inspeção Organização Produtos Processos
# 4708/5588
# Gestão Eventos Cooperacao
# 4709/5588
# Ferramentas Agile Gestão Projeto
# 4710/5588
# Mercado Tecnologia Plataforma Ferramentas
# 4711/5588
# Ferramentas Gestão Tecnologia Informação
# 4712/5588
# Profissões Manuais Trabalho Madeira
# 4713/5588
# Profissões Diversas Serviços Gerais
# 4714/5588
# Certificações TI Gerenciamento Projetos
# 4715/5588
# Habilidades Criativas Diversas
# 4716/5588
# Habilidades Fretadas Linguagem Avançada
# 4717/5588
# Habilidades Embalagem Cautelosa
# 4718/5588
# Ferramentas Edição RH Avançadas
# 4719/5588
# Gestão Processos Controle Pessoas
# 4720/5588
# Gestão Pessoas Processos RH
# 4721/5588
# Laboratório Fiscal Conhecimento Técnico
# 4722/5588
# Ferramentas Produtividade Gestão Tecnologia
# 4723/5588
# Análise Avançada Processamento Algoritmos
# 4724/5588
# Música Cultura Língua Turismo
# 4725/5588
# Análise Dados Geoespaciais Avan
# 4726/5588
# Sistemas Integrados Operacionais Avançados
# 4727/5588
# Sistemas Operacionais Avançados
# 4728/5588
# Sistema Qualidade Distribuição Tributação
# 4729/5588
# Sistemas Nuvem Atendimento Técnicos
# 4730/5588
# Análise Comportamento Certificação Hubspot
# 4731/5588
# Sistemas Propulsao Eletrica Técnicas
# 4732/5588
# Habilidades Avançadas de Vida
# 4733/5588
# Apoio Processos Vendas Tecnologia
# 4734/5588
# Ferramentas de Design Gráfico
# 4735/5588
# Gestão Projetos Pessoas Eficiência
# 4736/5588
# Segurança Infraestrutura Suporte Técnico
# 4737/5588
# Análise Fiscal Governamental Avançada
# 4738/5588
# Gestao Projetos Lideranca Equipe
# 4739/5588
# Gestão Projetos Técnicos Avanç
# 4740/5588
# Contabilidade Sistemas Análise Ferramentas
# 4741/5588
# Gestão Projetos Construção Certificação
# 4742/5588
# Manutenção Mecânica Gestão
# 4743/5588
# Manutenção Gestão Projetos Mecânica
# 4744/5588
# Desenvolvimento Web Ferramentas Especializadas
# 4745/5588
# Gestão Relações Consórcio Decisão
# 4746/5588
# Ferramentas CAD Edição Gráfica
# 4747/5588
# Gestão Tecnologia Monitoramento Sistemas
# 4748/5588
# Gestão Qualidade Sistemas Certificação
# 4749/5588
# Controle Processos Industriais Avancados
# 4750/5588
# Metodologias Agilidade Fisioterapia
# 4751/5588
# Técnicas Especializadas Análise Equipamentos
# 4752/5588
# Habilidades Linguagem Avançadas Processamento
# 4753/5588
# Ferramentas Business Intelligence Analytics
# 4754/5588
# Gerenciamento Projetos Certificação Ferramentas
# 4755/5588
# Técnicas de Desenvolvimento Ágil
# 4756/5588
# Desenvolvimento Ferramentas Metodologias Tecnológ
# 4757/5588
# Técnicas Médicas de Análise
# 4758/5588
# Habilidades Profissionais Eficazes
# 4759/5588
# Análise de Dados Avançada
# 4760/5588
# Técnicas Avançadas BIM
# 4761/5588
# Ferramentas Gestão Desenvolvimento Tecnológico
# 4762/5588
# Gestão Qualidade Sistemas Integrados
# 4763/5588
# Contencioso Segurança Qualidade Treinamento
# 4764/5588
# Logistica Gestao Administrativa
# 4765/5588
# Edição Gráfica Áudio Visual
# 4766/5588
# Desenvolvimento Web Ferramentas Avançadas
# 4767/5588
# Técnicas de Desenvolvimento Informática
# 4768/5588
# Desenvolvimento Rede Computação Certificação
# 4769/5588
# Operações Logísticas Avançadas
# 4770/5588
# Ferramentas Análise Dados Empresa
# 4771/5588
# Nomes Repetidos Outros Individuos
# 4772/5588
# Técnicas Gestão Tecnologia Avançadas
# 4773/5588
# Técnicas de Gestão Avançadas
# 4774/5588
# Edição Vídeo Ferramentas Profissionais
# 4775/5588
# Desenvolvimento Tecnologias Avançadas
# 4776/5588
# Análise Dados Ferramentas Tecnologia
# 4777/5588
# Habilidades Avançadas de Liderança
# 4778/5588
# Instalacoes Seguranca Tecnologia Avancada.
# 4779/5588
# Gestão Qualidade Sistemas Avançados
# 4780/5588
# Sistemas Operacionais Avançados Expert
# 4781/5588
# Gestão Sistemas Análise Desempenho
# 4782/5588
# Mercado Sustentabilidade Tecnologia Capacitação
# 4783/5588
# Adaptação Proatividade Organização Gerenciamento
# 4784/5588
# Sistemas Eletricos Desenvolvimento
# 4785/5588
# Sistemas Operacionais Vendas Gestao
# 4786/5588
# Gestão Liderança Abstração Delegação
# 4787/5588
# Sistemas Operacionais Estrutura Foco
# 4788/5588
# Gestão Projetos Qualidade Concreto
# 4789/5588
# Desenvolvimento Sistemas Análise
# 4790/5588
# Sistemas Integracao Gestao Tecnologia
# 4791/5588
# Gestão Técnicas Vendas Equipamentos
# 4792/5588
# Especialista em Plataformas Comércio
# 4793/5588
# Biomedicina Laboratorio Análise
# 4794/5588
# Vendas Suporte Design Conhecimento
# 4795/5588
# Desenvolvimento Humano Saúde
# 4796/5588
# Análise Técnica Rápida
# 4797/5588
# Gestão Comunicacao Analise Solucoes
# 4798/5588
# Gestão Pessoas Relacionamento Sucesso
# 4799/5588
# Análise Projetos Liderança Técnicas
# 4800/5588
# Eficiência Comercialização Experiência Tecnologia
# 4801/5588
# Desenvolvimento Humano Escalável Tecnologia
# 4802/5588
# Habilidades Diversas Gestão Contabilidade
# 4803/5588
# Design Grafica Tecnologia Producao
# 4804/5588
# Liderança Cooperativa Proatividade Desempenho
# 4805/5588
# Vendas Agendamento Gestão Análise
# 4806/5588
# Automação Sistemas Tecnologia Aviação
# 4807/5588
# Comunicação Inclusiva Plataformas Tecnológ
# 4808/5588
# Sistemas Vendas Itil Delphi
# 4809/5588
# Monitoramento Servicos Tecnologia Conhecimento
# 4810/5588
# Análise Dados UX Avançada
# 4811/5588
# Gerenciamento Residuos Solidos
# 4812/5588
# Gestão Operações Colheita Negócios
# 4813/5588
# Gestao Contabilidade Suporte Relacionamento
# 4814/5588
# Atenção Detalhes Foco Agilidade
# 4815/5588
# Habilidades Comunicação Eficaz
# 4816/5588
# Aprendizado Rápido Empatia Observação
# 4817/5588
# Gestão Suporte Contas Sustentabilidade
# 4818/5588
# Gestão Contábil Logística Operacional
# 4819/5588
# Análise de Processos Visão
# 4820/5588
# Desenvolvimento Criativo Multimidia Digital
# 4821/5588
# Análise Mercado Pesquisa Técnicas
# 4822/5588
# Análise Visão Mercado Estratégica
# 4823/5588
# Gestão Projetos Controle Contas.
# 4824/5588
# GNSS RTK Amadeus Sabre
# 4825/5588
# Instalação Eletricidade Infraestrutura Gest
# 4826/5588
# Sistemas Eletricos Relatorios Digitar
# 4827/5588
# Análise Sistemas Automatizados
# 4828/5588
# Gestão Pessoas Análise Matemática
# 4829/5588
# Gestão Laboratório Tecnologia Qualidade
# 4830/5588
# Análise Comunicação Desenvolvimento Estratégico
# 4831/5588
# Gestão Processos Análise Avançada
# 4832/5588
# Fabricação Liderança Análise Tecnologia
# 4833/5588
# Liderança Proatividade Soluções Práticas
# 4834/5588
# Gestao Equipes Alta Performance
# 4835/5588
# Testes Softwares Desenvolvimento Qualidade
# 4836/5588
# Processos Gestão Melhoria Técnicas
# 4837/5588
# Análise Processos Melhoria Contínua
# 4838/5588
# Testes Automacao Elaboracao Ferramentas
# 4839/5588
# Planejamento Logistica Gestao Vendas
# 4840/5588
# Modelagem Governança Segurança Inteligência
# 4841/5588
# Modelagem Processos Dados UML
# 4842/5588
# Testes Automatizados e Planejados
# 4843/5588
# Testes Automatizados Estratégias
# 4844/5588
# Análise Teste Desenvolvimento Ferramentas
# 4845/5588
# Planejamento Estratégico Gerencial
# 4846/5588
# Gestão Planejamento Vendas Ferramentas
# 4847/5588
# Planejamento Estratégico Qualidade Ferramentas
# 4848/5588
# Logistica Planejamento Analise Adaptacao
# 4849/5588
# Planejamento Estratégico Apoio
# 4850/5588
# Eficiência Operacional Avançada
# 4851/5588
# Estratégia Planejamento Visão
# 4852/5588
# Especialista Planejamento Estratégico
# 4853/5588
# Estratégia Planejamento Operacional
# 4854/5588
# Gestão Processos Análise Sinais
# 4855/5588
# Aprendizado Dinâmico Grupo
# 4856/5588
# Análise Produtividade Comunicação
# 4857/5588
# Conteúdo Multimídia Financeiro
# 4858/5588
# Mapeamento Processos Melhoria Sistemas
# 4859/5588
# Mapeamento Processos Gestão BPM
# 4860/5588
# Gerenciamento Produtividade Processos
# 4861/5588
# Análise Técnicas Gerenciamento Relatórios
# 4862/5588
# Gerenciamento Equipe Análise Financeira
# 4863/5588
# Operações Técnicas Ferramentas Venda
# 4864/5588
# Laboratório Práticas Avançadas
# 4865/5588
# Habilidades Avançadas Profissionais.
# 4866/5588
# Logística Vendas Tecnologia
# 4867/5588
# Segurança Treinamento Processamento Tecnológico
# 4868/5588
# Gestão Pecuária Planejamento Execução
# 4869/5588
# Gestão Processos Criativos Avançados
# 4870/5588
# Gestão Processos Qualidade IT
# 4871/5588
# Processos Industriais Avançados
# 4872/5588
# Otimizacao Processos Compras Conhecimento
# 4873/5588
# Gestão Processos Qualidade Pessoas
# 4874/5588
# Gestão Projetos Qualidade Técnicas
# 4875/5588
# Gestão Processos Químicos Vendas
# 4876/5588
# Vendas Gestão Técnicas Avançadas
# 4877/5588
# Gestão Processos Analise Avançada
# 4878/5588
# Gestão Projetos Processos Pessoas
# 4879/5588
# Gestão Sistemas Análise Relatórios
# 4880/5588
# Gestão Processos Qualidade Avançada
# 4881/5588
# Gestão Processos Qualidade Equipe
# 4882/5588
# Gestão Processos Projetos Qualidade
# 4883/5588
# Melhoria Processos Desenvolvimento Pessoas
# 4884/5588
# Controle Estatístico Processos Industriais
# 4885/5588
# Análise Dados Técnicas Avançadas
# 4886/5588
# Gestão Processos Melhoria Contínua
# 4887/5588
# Gerenciamento Projetos Arquitetura
# 4888/5588
# Gestao Mercado Marca Estudo
# 4889/5588
# Gestão de Processos Ambientais
# 4890/5588
# Gestão Processos Seleção Impressão
# 4891/5588
# Excelente Comunicação Eficaz
# 4892/5588
# Gestão Eventos Mercado Liderança
# 4893/5588
# Gestao Processos Empresa Excelencia
# 4894/5588
# Análise Processos Mapeamento Estratégico
# 4895/5588
# Riscos Inteligência Liderança Inovação
# 4896/5588
# Gestão Processos Varejo Cumprimento
# 4897/5588
# Gestão Processos Eficiência Organização
# 4898/5588
# Liderança Projetos Gestão Equipes
# 4899/5588
# Gestão Projetos Liderança Equipe
# 4900/5588
# Gestão Processos Engenharia Administrativa
# 4901/5588
# Gestão Processos Pessoas Eficiência
# 4902/5588
# Ferramentas de Gestão Avançadas.
# 4903/5588
# Conhecimento Processos Produtivos
# 4904/5588
# Processos Produtivos Melhoria Contínua
# 4905/5588
# Rapido Aprendizado Ensino Eficiente
# 4906/5588
# Comunicativa Dinamica Proativa Resolutiva
# 4907/5588
# Estatística Gestão Projetos Análise
# 4908/5588
# Gestao Projetos Análise Estatística
# 4909/5588
# Gestão Liderança Desenvolvimento Pessoal
# 4910/5588
# Ferramentas Gestão Integrada Técnicas
# 4911/5588
# Gestão Documentos Administração Eficiência
# 4912/5588
# Análise de Dados Estratégicos
# 4913/5588
# Sistemas Gestão Desenvolvimento Rápido
# 4914/5588
# Gestao de Processos Avançados
# 4915/5588
# Engenharia Operações Conciliação Proatividade
# 4916/5588
# Ciências Biológicas e Ambientais
# 4917/5588
# Gerenciamento Tecnologia Treinamento Manufatura
# 4918/5588
# Aprendizagem Fácil Foco Solução
# 4919/5588
# Adaptação Rápida Qualidade Foco
# 4920/5588
# Gestão Campanhas Técnicas Especializ
# 4921/5588
# Desenvolvimento Liderança Compras
# 4922/5588
# Ferramentas Manuais Técnicas
# 4923/5588
# Habilidades Sociais Profissionais
# 4924/5588
# Gestão Loja Caixa Técnicas
# 4925/5588
# Artística Técnica Motor
# 4926/5588
# Tecnologias Interacao Desenho Aprendizado
# 4927/5588
# Habilidades Sociais Comunicacao
# 4928/5588
# Habilidades Organizacionais Avançadas
# 4929/5588
# Aprendizado Fácil Empatia Útil
# 4930/5588
# Liderança Organizado Proativo Foco.
# 4931/5588
# Observador Proativo Otimista Profissional
# 4932/5588
# Equipamentos Técnicos Florestais Agrícolas
# 4933/5588
# Vendas Desenvolvimento Funil Línguas
# 4934/5588
# Gestão Projetos Tecnologia Inovação
# 4935/5588
# Gestão Relacionamento Pessoas
# 4936/5588
# Eletrônica Manutenção Qualidade Ferramentas
# 4937/5588
# Conteúdo Inteligente Família Vendas
# 4938/5588
# Agricola Equipamentos Manutencao
# 4939/5588
# Comunicativa Responsável Pontual Profissional
# 4940/5588
# Análise de Dados Ferramentas
# 4941/5588
# Análise de Dados Estratégicos
# 4942/5588
# Gestão Equipe Liderança Desempenho
# 4943/5588
# Gestão Equipe Liderança Desempenho
# 4944/5588
# Gestão Equipe Liderança Efetiva
# 4945/5588
# Gestão de Equipes Efetiva
# 4946/5588
# Comunicação Eficaz Trabalho Equipe
# 4947/5588
# Aprendizado Criativo Realista Inovador
# 4948/5588
# Atendimento Focado Qualidade Excelência
# 4949/5588
# Análise Conduz Relaciona Incentiva
# 4950/5588
# Atendimento Dinamico Empatia Eficacia
# 4951/5588
# Habilidades Organizacionais Adaptaveis
# 4952/5588
# Análise Rápida Habilidades Profissionais
# 4953/5588
# Tecnologia Contabilidade Liderança
# 4954/5588
# Habilidades Organizacionais Avançadas
# 4955/5588
# Habilidades Organizacionais Proativas
# 4956/5588
# Comunicativa Organizada Pontual
# 4957/5588
# Vendas Lógica Comunicação Eficaz
# 4958/5588
# Atenção ao Detalhe Profissional
# 4959/5588
# Gramática Assepsia Caixa Desenvolvimento
# 4960/5588
# Maquinário Operação Gestão Parceria
# 4961/5588
# Desenvolvimento Tecnologia Informação
# 4962/5588
# Atendimento Conhecimento Desenvolvimento
# 4963/5588
# Manutenção Veículos Engenharia Gestão
# 4964/5588
# Gestão Atendimento Rotinas Conhecimento
# 4965/5588
# Gestão Pessoas Vendas Projetos
# 4966/5588
# Gestão Projetos Infraestrutura
# 4967/5588
# Projeto Pesquisa Segurança Dinâmica
# 4968/5588
# Eletrica Mecanica Veiculos Expert
# 4969/5588
# Conhecimento Eletrica Avançado
# 4970/5588
# Desenvolvimento Liderança Qualidade Soluções
# 4971/5588
# Treinamento Gerenciamento Conhecimento Articulação
# 4972/5588
# Gestao Analise Criacao Tecnologia
# 4973/5588
# Gestão Estoques Avançada Experiência
# 4974/5588
# Adaptação Rápida Aprendizado Efet
# 4975/5588
# Aprendizado Rápido Comunicativo Flexível
# 4976/5588
# Logística Transporte Metrologia Condução
# 4977/5588
# Ferramentas Aeronaves Planejamento Precis
# 4978/5588
# Gestão Tecnologia Avançada Ferramentas
# 4979/5588
# Logistica Equipamentos Producao Montagem
# 4980/5588
# Análise Operacional Gestão Tecnologia
# 4981/5588
# Mecânica Autos Tecnologia Habilidades
# 4982/5588
# Liderança Estratégica Campanha Comercial
# 4983/5588
# Habilidades Sociais Técnicas Computacionais
# 4984/5588
# Comunicativa Proativa Inteligente Rápida
# 4985/5588
# Habilidades Comunicativas Profissionais
# 4986/5588
# Análise Projeto Resolução Efetiva
# 4987/5588
# Gestão Projetos Tecnologia Dados
# 4988/5588
# Análise de Conteúdo UX
# 4989/5588
# Análise Dados Engenharia Plataforma
# 4990/5588
# Análise Gestão Projetos Ferramentas
# 4991/5588
# Habilidades Comunicativas Proativas
# 4992/5588
# Comunicativa Proativa Etica Dinamica
# 4993/5588
# Conhecimento Contabil Indicadores Desempenho
# 4994/5588
# Gestão de Pessoas Resultados
# 4995/5588
# Inovação Liderança Criatividade Estratégia
# 4996/5588
# Eletrica Direcao Juridica Saude
# 4997/5588
# Desenvolvimento Produto Especialista Esportivo
# 4998/5588
# Habilidades Essenciais Grupo
# 4999/5588
# Gestão Criativa Organizacional
# 5000/5588
# Inovação Criatividade Proatividade
# 5001/5588
# Ideias Novas Soluções Criativos
# 5002/5588
# Manutenção Controle Qualidade Alimentos
# 5003/5588
# Gestão Segurança Tecnologia Pessoa
# 5004/5588
# Análise Classificação Contábil
# 5005/5588
# Desenvolvimento Tecnologia Gerenciamento Veiculos
# 5006/5588
# Criatividade Inovacao Humor Persuasao
# 5007/5588
# Ideias Novas e Criativas
# 5008/5588
# Liderança Comunicação Desafio Aprendizado
# 5009/5588
# Análise Dados Ciência Computação
# 5010/5588
# Conhecimento Técnico Jurídico Comercial
# 5011/5588
# Manutenção Equipamentos Registro Inspeção
# 5012/5588
# Análise Conflito Solução Agricultura
# 5013/5588
# Conhecimento Legislação e Higiene
# 5014/5588
# Legislação Higiene Limpeza
# 5015/5588
# Limpeza Eficaz Técnicas Profissionais
# 5016/5588
# Habilidades Comunicação Efetiva Profissional
# 5017/5588
# Habilidades de Liderança Profissional
# 5018/5588
# Gestão Produtos Qualidade Sustentável
# 5019/5588
# Liderança Organização Foco Dinamismo
# 5020/5588
# Habilidades Linguísticas Avançadas
# 5021/5588
# Liderança Vendas Detalhes Evolução
# 5022/5588
# Vontade Aprender Proatividade Força
# 5023/5588
# Vontade Aprender Crescer Inovar
# 5024/5588
# Vontade Aprender Crescer Desenvolver
# 5025/5588
# Habilidades Profissionais Dinâmicas
# 5026/5588
# Habilidades Sociais Interpessoais
# 5027/5588
# Design Criar Estudar Gosto
# 5028/5588
# Habilidades de Comunicação Eficaz
# 5029/5588
# Habilidades Profissionais de Excelência
# 5030/5588
# Comunicação Eficaz Humana Profissional
# 5031/5588
# Liderança Gestão Comunicação Tecnologia
# 5032/5588
# Habilidades Cognitivas Avançadas
# 5033/5588
# Gerenciamento Projetos Multimidia Relatórios
# 5034/5588
# Entregas Gestão Comércio Exterior
# 5035/5588
# Gestão Faturamento Atendimento Fornecedores
# 5036/5588
# Gestão Qualidade Vendas Técnicas
# 5037/5588
# Vendas Técnicas Direito Conhecimento
# 5038/5588
# Atendimento Vendas Imóveis Inglês
# 5039/5588
# Análise Dados Cloud Experiência
# 5040/5588
# Vendas Compras Inclusão Culinária
# 5041/5588
# Midias Sociais Conteúdo Atendimento
# 5042/5588
# Vendas Caixa Atendimento Sistemas
# 5043/5588
# Vendas Externas Diretas Indicadores
# 5044/5588
# Análise Contratos UX Oramento
# 5045/5588
# Análise Desempenho Diversas Áreas
# 5046/5588
# Desenvolvimento Talentos Vendas Delphi
# 5047/5588
# Gestão Liderança Conhecimento Integração
# 5048/5588
# Análise Experiência Setor Imobiliário
# 5049/5588
# Vendas Comercial Protheus Iafox
# 5050/5588
# Desenvolvimento Tecnológico Vendas B2B
# 5051/5588
# Vendas Experiência Marcenaria Adquirencia
# 5052/5588
# Experiência Usuário Tecnologia Vendas
# 5053/5588
# Atendimento Vendas Sistemas Experiência
# 5054/5588
# Gestão Equipes Dados Vendas
# 5055/5588
# Gestão Logística e Vendas
# 5056/5588
# Habilidades Comunicativas Avançadas
# 5057/5588
# Análise Estratégica Contabilidade Desempenho
# 5058/5588
# Atendimento Profissional Qualidade Foco
# 5059/5588
# Contabilidade Saúde Decoração Habilidades
# 5060/5588
# Contabilidade Mediar Conflitos Técnicas
# 5061/5588
# Análise Contabilidade Gerenciamento
# 5062/5588
# Habilidades Linguagem Avançadas Profissionais
# 5063/5588
# Habilidades Comunicacao Eficaz Gerencial
# 5064/5588
# Gestão Riscos Qualidade Projeto
# 5065/5588
# Liderança Projetos Ética Controle
# 5066/5588
# Gestão Equipes Crianças Pesquisa
# 5067/5588
# Desenvolvimento Conteúdo Relacionamento
# 5068/5588
# Análise Gerenciamento Desenvolvimento
# 5069/5588
# Gestão Recursos Contabilidade Análise
# 5070/5588
# Gestao Projetos Qualidade Certificacao
# 5071/5588
# Atendimento Conteineres Orquestracao
# 5072/5588
# Vendas Design Pesquisa Ballet
# 5073/5588
# Vendas Pecas Jardinagem Experiência
# 5074/5588
# Gestão Tecnologia Saúde Vendas
# 5075/5588
# Projeto Engenharia Química Técnicas
# 5076/5588
# Cirurgia Laboratório Manutenção Negócios
# 5077/5588
# Gestão Atendimento Conhecimento Técnicas
# 5078/5588
# Atendimento Agilidade Compras Liderança
# 5079/5588
# Gestao Pessoas Executivo Contas
# 5080/5588
# Calculo Vendas Escritorio Gestao
# 5081/5588
# Habilidades Comerciais Categoria
# 5082/5588
# Experiencia Variedade Skills Diversos
# 5083/5588
# Gestão Logística Vendas Técnicas
# 5084/5588
# Desenvolvimento Pessoal Tecnologia Gestão
# 5085/5588
# Gestão Vendas Habilidades Técnicas
# 5086/5588
# Habilidades Gerais Profissionais Variadas
# 5087/5588
# Ferramentas Business Intelligence
# 5088/5588
# Mecânica Onetrust FLV Jardinagem
# 5089/5588
# Gestão Projetos Visão Integrada
# 5090/5588
# Gestão Projetos Comunicação Dinâmica
# 5091/5588
# Hidraulica Manutencao Avançadas
# 5092/5588
# Gestão Comercial Desenvolvimento Pessoas
# 5093/5588
# Genética Análise Desenho Multimídia
# 5094/5588
# Habilidades Ambientais Vendas
# 5095/5588
# Gestão Colaboração Análise Visão
# 5096/5588
# Análise Comunicação Foco Profissional
# 5097/5588
# Proativa Entusiasmada Pontual
# 5098/5588
# Atencioso Respeitoso Tecnico Agil
# 5099/5588
# Liderança Gestão Pessoas Equipes
# 5100/5588
# Responsável Organizado Pontualmente
# 5101/5588
# Gestão Processos Desenvolvimento Habilidades
# 5102/5588
# Atendimento Proativo e Prestativo
# 5103/5588
# Gestao Vendas Linguagem Basico
# 5104/5588
# Excelente Foco em Serviços
# 5105/5588
# Comunicativa Proativa Resiliente Ajudar
# 5106/5588
# Habilidades Gerais Profissionais
# 5107/5588
# Iniciativa Proatividade Empreendedorismo Lider
# 5108/5588
# Ação Eficaz Tomada Rápida
# 5109/5588
# Aprendo Rápido e Foco
# 5110/5588
# Rápido Aprendizado Facilidade Adaptabilidade
# 5111/5588
# Gestão Produção Construção Civil
# 5112/5588
# Trabalho Organizacao Eficiencia
# 5113/5588
# Habilidades Suporte Contabil Resolutiva
# 5114/5588
# Habilidades Técnicas Avançadas
# 5115/5588
# Excelente Organização Escrita Profissional
# 5116/5588
# Habilidades Sociais Avançadas
# 5117/5588
# Produção Gráfica Técnica Eletrôn
# 5118/5588
# Comunicação Eficaz Aprendizado Rápido
# 5119/5588
# Vendas Atendimento Fácil Aprendizado
# 5120/5588
# Habilidades Empreendedoras Pessoais
# 5121/5588
# Comunicação Positiva Proativa Eficiente
# 5122/5588
# Gestão Ágil e Eficaz
# 5123/5588
# Tecnologia Suporte Regulatório Desenho
# 5124/5588
# Gestão RH e Tecnologia
# 5125/5588
# Autocad Remoto IT Suporte
# 5126/5588
# Análise Dados Cloud TI
# 5127/5588
# Desenvolvimento Power BPF CI
# 5128/5588
# Ferramentas Gráficas Business Inteligência
# 5129/5588
# Aprendizado Rápido Excelência
# 5130/5588
# Rapidez Aprendizado Atenção Dinamismo
# 5131/5588
# Operações Fabris e Limpeza
# 5132/5588
# Gatilhos Técnicas Operacionais
# 5133/5588
# Operações Logísticas Manutenção Veículos
# 5134/5588
# Habilidades Sociais Profissionais
# 5135/5588
# Habilidades Sociais Profissionais
# 5136/5588
# Agronegocio Gestao Qualidade
# 5137/5588
# Conhecimentos Contábeis e Alimentícios
# 5138/5588
# Treinamento Eletrônica Atendimento Técn
# 5139/5588
# Equipamentos Gestão Eventos Técnicos
# 5140/5588
# Habilidades de Liderança Profissional
# 5141/5588
# Gestão Pessoas Habilidades Avanç
# 5142/5588
# Energia Eletrica Veiculos Carga
# 5143/5588
# Aprendizado Rápido Liderança Proatividade
# 5144/5588
# Habilidades Diversas Profissionais Úteis
# 5145/5588
# Vendas Negociação Habilidades Avançadas
# 5146/5588
# Negociação Eficaz Comunicação
# 5147/5588
# Desenvolvimento Treinamento Contínuo Conhecimento
# 5148/5588
# Gestão Negócios Comunicação
# 5149/5588
# Habilidades Profissionais Essenciais
# 5150/5588
# Gestão Qualidade Atendimento Soluções
# 5151/5588
# Análise Dados Linguagem Humana
# 5152/5588
# Competente Proativo Responsável Dinâmico
# 5153/5588
# Comunicativa Dinamica Inteligente
# 5154/5588
# Tecnico Eletrica Mecanica Suporte
# 5155/5588
# Tecnico Vendas Dominio Habil
# 5156/5588
# Aprendizado Rápido Adaptação Efic
# 5157/5588
# Excelente Gestão Organizacional
# 5158/5588
# Inovação Gestão Detalhes Organizacionais
# 5159/5588
# Organização Atenção Detalhes
# 5160/5588
# Gestão Projetos Controle Relacionamento
# 5161/5588
# Análise Estratégia Projeto Segurança
# 5162/5588
# Aprendizado Rápido Confiante Eficaz
# 5163/5588
# Resolução Problemas Comunicação Eficaz
# 5164/5588
# Habilidades Comunicacao Rapida Excelente
# 5165/5588
# Rapido Proativo Aprendizado Eficiente
# 5166/5588
# Trabalho Equipe Comunicação Aprendizado
# 5167/5588
# Habilidades Diversas Profissionais
# 5168/5588
# Organizacao Colaboracao Criatividade Agilidade
# 5169/5588
# Comunicação Organização Proatividade
# 5170/5588
# ...
# 5240/5588
# Gestao Automacao Vendas Treinamento
# 5241/5588
# Habilidades Dinâmicas Profissionais
# 5242/5588
# Liderança Vendas Calculos ICMS
# 5243/5588
# Contabilidade Treinamento Comunicação Análise
# 5244/5588
# Liderança Equipes Gestão Desempenho
# 5245/5588
# Liderança Equipes Desenvolvimento Pessoal
# 5246/5588
# Comunicativa Proativa Colaborativa
# 5247/5588
# Vendas Atendimento Contas Figma
# 5248/5588
# Gestão Cultura Organizacional
# 5249/5588
# Gestão Organização Eficiência Prazos
# 5250/5588
# Defesa Imobiliaria Prospeccao Vendas
# 5251/5588
# Desempenho Liderança Aprendizado Empat
# 5252/5588
# Eficiência Organização Atenção Agilidade
# 5253/5588
# Análise Sistêmica Escrita Científica
# 5254/5588
# Testes Técnicas Avançadas
# 5255/5588
# Desenvolvimento Ágil Codificação Eficiente
# 5256/5588
# Vendas Eficazes Gestao Pessoal
# 5257/5588
# Gestão Ágil Organizacional Efetiva
# 5258/5588
# Equipe Foco Qualidade Agilidade
# 5259/5588
# Aprendizado Focado Visão Geral
# 5260/5588
# Gestao Mudanca Planejamento Estrategia
# 5261/5588
# Colaboração Aprendizado Consumidor
# 5262/5588
# Excelente Comunicação Grupo
# 5263/5588
# Gestão Controle Logística Operações
# 5264/5588
# Técnicas Apresentação Correção Processamento
# 5265/5588
# Máquinas Operações Estética Técnicas
# 5266/5588
# Organização Atenção Detalhes
# 5267/5588
# Gestao de Frotas Variadas
# 5268/5588
# Análise de Dados Técnicos
# 5269/5588
# Comunicativa Dinamica Pro Ativa
# 5270/5588
# Comunicativa Dinamica Profissional
# 5271/5588
# Gestão Indicadores Bancários
# 5272/5588
# Análise Legislação Ambiental
# 5273/5588
# Gestão Processos Segurança Eficiência
# 5274/5588
# Análise Técnicas Comunicação Profissional
# 5275/5588
# Aprendizado Rápido Foco Numérico
# 5276/5588
# Aprendizado Rápido Equipe Colaborativa
# 5277/5588
# Liderança Gestão Contas Recrutamento
# 5278/5588
# Fiscalidade Qualidade Gestão RH
# 5279/5588
# Organização Gestão Desenvolvimento Eficiência
# 5280/5588
# Organizacao Agilidade Competitividade Técnicas
# 5281/5588
# Conhecimento Diversificado Profissional
# 5282/5588
# Farmácia Engenharia Equipamentos
# 5283/5588
# Conhecimento UX Copy Net
# 5284/5588
# Liderança Estratégica Controle Financeiro
# 5285/5588
# Comunicacao Lideranca Aprendizado Inovacao
# 5286/5588
# Habilidades Técnicas Comerciais
# 5287/5588
# Gestão Análise Comportamental Segurança
# 5288/5588
# Gestao Vendas Kpis Truck
# 5289/5588
# Edição Técnica Linguagem Avançada
# 5290/5588
# Conhecimento Técnico Avançado
# 5291/5588
# Gestão Controle Operação Fornecedores
# 5292/5588
# Gestão Compras Plataformas Merchandising
# 5293/5588
# Treinamento Animais Serviços Manuais
# 5294/5588
# Vontade Aprender Trabalhar Vencer
# 5295/5588
# Personalidade Dinâmica Foco
# 5296/5588
# Habilidades Sociais Profissionais
# 5297/5588
# Gestão de Projetos Construção
# 5298/5588
# Gestão de Documentos Fiscais
# 5299/5588
# Gestao de Produtos Relatorios
# 5300/5588
# Motivação Forte Desenvolvimento Pessoal
# 5301/5588
# Aprendizado Rápido e Fácil
# 5302/5588
# Domínio Técnico Avançado
# 5303/5588
# Logística Armazenagem Engenharia Inventario
# 5304/5588
# Proatividade Organizacao Aprendizado Excel
# 5305/5588
# Gestão Eficaz Organização
# 5306/5588
# Segurança Liderança Técnicas Estratégicas
# 5307/5588
# Aprendizado Facilidade Projeto Senso
# 5308/5588
# Conhecimento Tributário Fiscal
# 5309/5588
# Conhecimento Técnico Avançado At
# 5310/5588
# Senso Organizacao Eficacia
# 5311/5588
# Habilidades Organizacionais Avançadas
# 5312/5588
# Estratégia Organização Proativa
# 5313/5588
# Gestão Organização Proatividade
# 5314/5588
# Desenvolvimento Segurança Tecnologias
# 5315/5588
# Desenvolvimento Liderança Equipe Aprendizado
# 5316/5588
# Gestão Liderança Comunicação Efetiva
# 5317/5588
# Técnicas Diversas Profissional Útil
# 5318/5588
# Liderança Arquitetura Equipe Serviço
# 5319/5588
# Habilidades Mentais Avançadas
# 5320/5588
# Especialista em Vendas e Tecnologia
# 5321/5588
# Gestão Pessoas Habilidades Variadas
# 5322/5588
# Análise Dados TOTVS MR
# 5323/5588
# Gestão Infraestrutura Vendas Técnicas
# 5324/5588
# Técnicas de Persuasão Vendas
# 5325/5588
# Gestão Recursos Planejamento Tecnologia
# 5326/5588
# Impressão Sascar Treinamento Avançado
# 5327/5588
# Análise Estratégica Regras Funcionais
# 5328/5588
# Matemática Vendas Bebidas Tributação
# 5329/5588
# Habilidades Sociais Humanas Essenciais
# 5330/5588
# Análise Sensível Método Pacífico
# 5331/5588
# Análise Rápida Ação Eficaz
# 5332/5588
# Excelente Comunicação Ética Detalhe
# 5333/5588
# Artes Decorativas Proteção Culturas
# 5334/5588
# Gestão Processos Empresa Eficiência
# 5335/5588
# Gestao Obras e Riscos
# 5336/5588
# Habilidades Comunicativas Proativas
# 5337/5588
# Habilidades Profissionais Dinâmicas
# 5338/5588
# Desenvolvimento Humano Conteúdo Serviço
# 5339/5588
# Emissao Notas Fiscais
# 5340/5588
# Gestão de Projetos Criativos
# 5341/5588
# Análise Dados Logística Financeiro
# 5342/5588
# Liderança Gestão Resíduos Pessoas
# 5343/5588
# Gestão Compras Marketing Conteúdo
# 5344/5588
# Análise Técnica Matemática Gerencial
# 5345/5588
# Gestão Pessoas Desempenho Lider
# 5346/5588
# Técnicas Avançadas, Comunicação,
# 5347/5588
# Gestão Pessoas Habilidades Liderança
# 5348/5588
# Gestão Pessoas Liderança Desempen
# 5349/5588
# Gestão Pessoas Habilidades Liderança
# 5350/5588
# Gestão Pessoas Habilidades Liderança
# 5351/5588
# Gestão Pessoas Liderança Desenvolvimento
# 5352/5588
# Gestão TI Segurança Criativa
# 5353/5588
# Gestão Processos Administrativos
# 5354/5588
# Gestão Trafego Relatórios Obras
# 5355/5588
# Conhecimento Técnicas Processamento Produtividade
# 5356/5588
# Conhecimento Avançado em Inglês
# 5357/5588
# Gestão Recursos Humanos
# 5358/5588
# Gestao Desempenho Colaboracao Efet
# 5359/5588
# Habilidades Vendas Persuasivas Observação
# 5360/5588
# Conhecimento Técnicas Manutenção Veículos
# 5361/5588
# Técnicas Inteligência Business
# 5362/5588
# Análise Dados Inteligência Artificial
# 5363/5588
# Análise Matemática Colaborativa
# 5364/5588
# Habilidades Manuais Diversas Profissionais
# 5365/5588
# Aprendizado Ágil e Inovação
# 5366/5588
# Gestão Mudanças Organizacionais Estratégicas
# 5367/5588
# Gestao e Controle Operacional
# 5368/5588
# Sistemas Gestão Serviços Tecnologia
# 5369/5588
# Habilidades Sociais Profissionais
# 5370/5588
# Vendas Línguas Empatia Aprend
# 5371/5588
# Atencioso Proativo Esforcado Aprendiz
# 5372/5588
# Gestao Vendas Cobranca Recursos
# 5373/5588
# Gestão de Custos Pneus
# 5374/5588
# Ajudar Foco Dinamico Versatil
# 5375/5588
# Habilidades Decisão Eficaz
# 5376/5588
# Habilidades Decisões Estratégicas
# 5377/5588
# Análise Crítica Comunicação Efetiva
# 5378/5588
# Suporte Técnico Cultural
# 5379/5588
# Análise Pesquisa Observação Cobrança
# 5380/5588
# Gestão de Obras Avançadas
# 5381/5588
# Análise Crítica Tomada Decisão
# 5382/5588
# Conhecimento Análise Processamento Ferramentas.
# 5383/5588
# Aprendizado Empático Focado Efetivo
# 5384/5588
# Foco Atento Comunicacao Eficaz
# 5385/5588
# Habilidades Decisão Eficaz
# 5386/5588
# Habilidades Decisões Estratégicas
# 5387/5588
# Tecnologias Informação Conhecimento Análise
# 5388/5588
# Vendas e Conhecimento Geral
# 5389/5588
# Habilidades Sociais Profissionais
# 5390/5588
# Análise Rápida Confidencial
# 5391/5588
# Habilidades Interpessoais Avançadas
# 5392/5588
# Ferramentas Planejamento Vendas Sociais
# 5393/5588
# Conhecimento Diverso em Áreas
# 5394/5588
# Habilidades de Aprendizado Rápido
# 5395/5588
# Gestao Maquinas Atendimento Financeiro
# 5396/5588
# Comunicativa Pontual Proativa
# 5397/5588
# Comunicativo Pontual Prestativo
# 5398/5588
# Análise Dados Power LGPD
# 5399/5588
# Conhecimento Processamento Atencao Farmaceutica
# 5400/5588
# Desenvolvimento Sistemas Graficos Conhecimento
# 5401/5588
# Habilidades Gerais Profissionais
# 5402/5588
# Proativo Pontual Dinamico
# 5403/5588
# Fusões Gestão Dinâmica Pessoas
# 5404/5588
# Atenção Foco Qualidade Agilidade
# 5405/5588
# Trabalho Equipe Comunicação
# 5406/5588
# Habilidades Profissionais Elevadas
# 5407/5588
# Habilidades Sociais Profissionais
# 5408/5588
# Habilidades Comunicacao Eficaz
# 5409/5588
# Habilidades Profissionais Elevadas
# 5410/5588
# Habilidades Linguísticas Multitarefa
# 5411/5588
# Gestão Categoria e Treinamento
# 5412/5588
# Habilidades Profissionais Elevadas
# 5413/5588
# Habilidades Profissionais Alto Desempenho
# 5414/5588
# Medição Regulação Farmacêutica
# 5415/5588
# Gestao Projetos Analise Didatica
# 5416/5588
# Biotecnologia Farmacêutica legislação
# 5417/5588
# Liderança Gestão Desenvolvimento Pessoal
# 5418/5588
# Análise Crítica Tomada Decisão
# 5419/5588
# Excelente Julgamento Crítica Objetiva
# 5420/5588
# Aprendizado Rápido Proativo Confiança
# 5421/5588
# Produtos Alimentícios Logística Gerenciamento
# 5422/5588
# Conhecimento Sistema Dominio Avançado
# 5423/5588
# Gestão Segurança Tecnologia Inovação
# 5424/5588
# Prospeccao Tecnicas Alimentos Sanitaria
# 5425/5588
# Agricultura Desenvolvimento Gestão Plantas
# 5426/5588
# Tecnologias Agronomicas Avançadas
# 5427/5588
# Desenvolvimento Avaliação Treinamento
# 5428/5588
# Produção Processos Planejamento Conhecimento
# 5429/5588
# Gestão Produção Processos Avançados
# 5430/5588
# Soldagem Química Farmácia Manipulação
# 5431/5588
# Produtos Químicos Processamento Papel
# 5432/5588
# Gestão Saúde Transformação Pessoal
# 5433/5588
# Ferramentas Criacao Matematica Comercio
# 5434/5588
# Desenvolvimento RPA HSE Delphi
# 5435/5588
# Liderança Comunicação Flexibilidade Estratégia
# 5436/5588
# Habilidades Observação Detalhada
# 5437/5588
# Gestão Indicadores Relatórios Gráficos
# 5438/5588
# Gestão Família Contabilidade Processos
# 5439/5588
# Aprendizado Rápido Foco Disciplina
# 5440/5588
# Habilidades de Foco Adaptável
# 5441/5588
# Segurança Vigilância Gestão Matemática
# 5442/5588
# Tecnologias Infraestrutura Liderança
# 5443/5588
# Contabilidade Analise Elaboracao
# 5444/5588
# Aprendizado Rápido Ética Confiabilidade
# 5445/5588
# Conhecimento Bebidas Experiência Contábil
# 5446/5588
# Aprendizado Rápido Escrita Técnica
# 5447/5588
# Aprendizado Rápido Análise Dinâmica
# 5448/5588
# Rapidez Aprendizado Linguagem Avanç
# 5449/5588
# Aprendizado Contínuo Proativo
# 5450/5588
# Gestão Identidades Criativas Atendimento
# 5451/5588
# Diversas Habilidades Profissionais
# 5452/5588
# Privacidade Conformidade Desenvolvimento Corporativo
# 5453/5588
# Gestão Contabilidade Análise Coordenação
# 5454/5588
# Análise Estratégica Resultados Eficientes
# 5455/5588
# Liderança Comunicação Eficaz Gestão
# 5456/5588
# Gestão de Processos Avançados
# 5457/5588
# Gestão Projetos Qualidade Inovação
# 5458/5588
# Análise Técnicas Diversas Habilidades
# 5459/5588
# Habilidades de Escuta Ativa
# 5460/5588
# Habilidades Comunicacao Eficaz
# 5461/5588
# Aprendizado Proativo Iniciativa Eficaz
# 5462/5588
# Aprendizado Rápido Análise Focado
# 5463/5588
# Aprendizado Rápido Criativo Inovador
# 5464/5588
# Gestão Análise Desenvolvimento Liderança
# 5465/5588
# Análise de Dados Proteção Conteúdo
# 5466/5588
# Desenvolvimento Comercial Beleza Tendências
# 5467/5588
# Aprendizado Rápido Ensino Criativo
# 5468/5588
# Habilidades Comunicação Eficaz.
# 5469/5588
# Fabricacao Grafica Metalurgia Tintas
# 5470/5588
# Acolhimento Técnico Dinâmico
# 5471/5588
# Ergonomia Desenvolvimento Autonomo
# 5472/5588
# Gestão Comportamental Visão Sistemica
# 5473/5588
# Desenvolvimento Sistemas Químicos Eletricos
# 5474/5588
# Operações Logísticas Contabilidade Técnicas
# 5475/5588
# Cimento Construção Manutenção Processos
# 5476/5588
# Conhecimento Técnicas Variadas Profissional
# 5477/5588
# Sistemas ERP e Gestão
# 5478/5588
# Desenvolvimento Tecnológico Agile
# 5479/5588
# Engenharia Técnica Construção
# 5480/5588
# Técnicas Avançadas Processamento
# 5481/5588
# Gestão Segurança Desenho Liderança
# 5482/5588
# Testes Infraestrutura Negócios
# 5483/5588
# Atendimento Laboratorio Regulatorio Goiania
# 5484/5588
# Mecânica Tributação Vendas Operação
# 5485/5588
# Logística Técnicas Especializadas
# 5486/5588
# Avaliação Comportamento Produção Legislação
# 5487/5588
# Equipamentos Rotas Operacao Tecnicas
# 5488/5588
# Gestão Governança Sociais Tecnologia
# 5489/5588
# Gestão Infraestrutura Contabilidade
# 5490/5588
# Conhecimento Tecnologia Emergente
# 5491/5588
# Gestão Serviços Qualidade Sistemas
# 5492/5588
# Condução Veículos Manutenção Equipamentos
# 5493/5588
# Materiais Processamento Distribuição Organização
# 5494/5588
# Logística Gerenciamento Almoxarifado
# 5495/5588
# Técnicas de Desenvolvimento Integrado.
# 5496/5588
# Vendas Atendimento Técnicas Etiqueta
# 5497/5588
# Gestão Comercial Logística Tecnologia
# 5498/5588
# Pesquisa Desenvolvimento Operações Carnes
# 5499/5588
# Gestão Qualidade e Estratégia
# 5500/5588
# Gestão Dados Arquitetura Planejamento
# 5501/5588
# Materiais Processamento Técnicas Avançadas
# 5502/5588
# Boas Praticas Fabricacao Processos
# 5503/5588
# Fabricação Normas Qualidade Boas
# 5504/5588
# Fabricação Mecânica Processos Técnicos
# 5505/5588
# Conhecimento Materiais Construção Técnicas
# 5506/5588
# Desenvolvimento Criativo Grafico Técnico
# 5507/5588
# Análise Classificação Controle
# 5508/5588
# Manipulação Alimentos Produção Técnicas
# 5509/5588
# Gestão Produção Processos Industriais
# 5510/5588
# Gestão Contábil Avançada Tecnologia
# 5511/5588
# Análise Dados Saúde Migração
# 5512/5588
# Conhecimento Técnico Avançado
# 5513/5588
# Produção Conteúdo Gestão Treinamento
# 5514/5588
# Legislação Limpeza Equipamentos Produtos
# 5515/5588
# Técnicas Seleção Conteúdo Sistemas
# 5516/5588
# Gestão Produção Qualidade Inspeção
# 5517/5588
# Limpeza Produtos Equipamentos
# 5518/5588
# Gestão Serviços Tecnologia Avançada
# 5519/5588
# Análise Legislação Comércio Exterior
# 5520/5588
# Técnicas Avançadas Operacionais
# 5521/5588
# Gestão Produção Inovação Tecnologia
# 5522/5588
# Gestão Produção Desenvolvimento Tecnologia
# 5523/5588
# Análise Avaliação ConteúdoLegislação
# 5524/5588
# Sistemas Globais Santri Cronos
# 5525/5588
# Conhecimento Técnico Construção Gerenciamento
# 5526/5588
# Gestão Técnica Operacional Avanç
# 5527/5588
# Análise de Dados Visuais
# 5528/5588
# Viagens Vendas Caixa Conciliação
# 5529/5588
# Hidraulica Mecanica Maquinacao
# 5530/5588
# Marcas Costura Tasy Pecas
# 5531/5588
# Tributos Moda Vendas Técnicas
# 5532/5588
# Mecânica Hidráulica Serralher
# 5533/5588
# Culturas Hidropônicas Valor Alimentício
# 5534/5588
# Sistemas Saúde Anvisa Domínio
# 5535/5588
# Vendas Serviços Bancários Empatia
# 5536/5588
# Técnicas Vendas Maquinas Suframa
# 5537/5588
# Costura Gestão Arte Segurança
# 5538/5588
# Logística Carga Atendimento Técnico
# 5539/5588
# Gestão Desenvolvimento Conhecimento Alimentos
# 5540/5588
# Eletronica Atendimento Radioprotecao Geracao
# 5541/5588
# Diversidade de Conhecimentos Profissionais
# 5542/5588
# Mecânica Ferramentas Aulas Coletivas
# 5543/5588
# Análise Técnicas Especializadas
# 5544/5588
# Sistemas Contábeis Saúde Gerenciais
# 5545/5588
# Sistemas ERP Cloud GSuite
# 5546/5588
# Sistemas ERP de Gestão
# 5547/5588
# Sistemas ERP e Atendimento
# 5548/5588
# Logística Segurança Conhecimento Técnico
# 5549/5588
# Panificação Técnicas Culinárias Armazenamento
# 5550/5588
# Pesquisa Aplicada Comunicação Eficaz
# 5551/5588
# Eletrica Seguranca Logistica
# 5552/5588
# Manutenção Eletrônica Mecânica
# 5553/5588
# Especialista Gestão Ambiente Snowflake
# 5554/5588
# Gestão Qualidade Tecnologia Conhecimento
# 5555/5588
# Vendas Tecnologia Manutenção Processos
# 5556/5588
# Desenvolvimento Conteúdo Tecnologia Alimentação
# 5557/5588
# Técnicas Construção Desenvolvimento Ferramentas
# 5558/5588
# Tecnologia Alimentos Soluções Vendas
# 5559/5588
# Ferroviário Farmacêutico Pet
# 5560/5588
# Gestão Ambiental Segurança Operacional
# 5561/5588
# Logistica Vendas Producao Tecnologia
# 5562/5588
# Contabilidade Negociação Custo Eficiência
# 5563/5588
# Gestao Logistica Operacional
# 5564/5588
# Segurança Veículos Administração Construção
# 5565/5588
# Análise Dados Visuais Colaboração
# 5566/5588
# Gestão Projetos Tecnologia Treinamento
# 5567/5588
# Laboratório Experiência Floresta Atendimento
# 5568/5588
# Desenvolvimento Infraestrutura Dados Office
# 5569/5588
# Tratamento Piso Maquina Cereais
# 5570/5588
# Desenvolvimento Liderança Gestão Pessoas
# 5571/5588
# Análise Desenvolvimento Apresentação Otimização
# 5572/5588
# Gestão Compras Parcerias Cozinha
# 5573/5588
# Técnicas Variadas Suporte Tecnico
# 5574/5588
# Soluções SaaS Marca Consumidor
# 5575/5588
# Agricultura Tecnologia Inovação
# 5576/5588
# Vendas Serviços Técnicas Sistemas
# 5577/5588
# Gestão Conhecimento Serviço Humano
# 5578/5588
# Desenvolvimento Treinamento Consumidor
# 5579/5588
# Gestão Conhecimento Desenvolvimento Técnicas
# 5580/5588
# Atendimento Cultural Treinamento Profissional
# 5581/5588
# Projetos Técnicos Desenvolvimento
# 5582/5588
# Gestão Logística Treinamento Desenvolvimento
# 5583/5588
# Conhecimento Técnico Contínuo
# 5584/5588
# Atendimento Contábil Bancário Constitucional
# 5585/5588
# Desenvolvimento Tecnico Comercial
# 5586/5588
# Treinamento Desenvolvimento Pessoal Profissional
# 5587/5588
# Treinamento Desenvolvimento Cidade Chaoeco
# 5588/5588
# Clusterização Nível 0 Concluída a partir da iteração 4124

# %%
df_final[f"nome_n0"] = df_final[f"cluster_n0"].map(nomes)
# Junção
df_json_aux = df_final.to_dict(orient="records")
with open("/kaggle/working/visualizacao_clusters_aux.json", "w", encoding="utf-8") as f:
    json.dump(df_json_aux, f, ensure_ascii=False, indent=2)

# %%
# ---- GERAÇÃO DOS CLUSTERS NIVEL 1 (INTERMEDIARIO) ----

from sklearn.cluster import AgglomerativeClustering
import json
import pandas as pd

# Carregue o JSON em uma lista de dicionários
with open("/kaggle/working/visualizacao_clusters.json", "r", encoding="utf-8") as f:
    dados = json.load(f)

# Converta para DataFrame
df_final = pd.DataFrame(dados)

# Calcule centroides e nomes (ordem garantida)
centroides = []
nomes_n0 = []
clusters_n0_validos = []
for c in sorted(df_final['cluster_n0'].unique()):
    if c == -1:
        continue
    pontos = df_final[df_final['cluster_n0'] == c]
    centroides.append([pontos['x'].mean(), pontos['y'].mean()])
    nomes_n0.append(pontos['nome_n0'].iloc[0])
    clusters_n0_validos.append(c)
centroides = np.array(centroides)

# Agglomerative clustering
n_clusters_nivel1 = 150
cluster_model = AgglomerativeClustering(n_clusters=n_clusters_nivel1, linkage='ward')
labels_nivel1 = cluster_model.fit_predict(centroides)

# Nomeação dos superclusters
nomes_nivel1 = {}
for super_c in sorted(np.unique(labels_nivel1)):
    clusters_filhos = [i for i, l in enumerate(labels_nivel1) if l == super_c]
    nomes_filhos = [nomes_n0[i] for i in clusters_filhos]
    nome_super = nomear_cluster(nomes_filhos, nivel=1)
    nomes_nivel1[super_c] = nome_super

# Mapeando cluster_n0 para o supercluster_n1
cluster_n0_to_n1 = {c: labels_nivel1[i] for i, c in enumerate(clusters_n0_validos)}
df_final['cluster_n1'] = df_final['cluster_n0'].map(cluster_n0_to_n1)
df_final.loc[df_final['cluster_n0'] == -1, 'cluster_n1'] = -1

df_final['nome_n1'] = df_final['cluster_n1'].map(nomes_nivel1)
df_final.loc[df_final['cluster_n1'] == -1, 'nome_n1'] = "Ruído"

print("Clusterização Nivel 1 Concluída")
# Out:
# Proatividade Foco Implementação
# Gestão de Riscos
# Vendas Liderança Online
# Análise Dados TI
# Desenvolvimento Software Linux
# Marketing Digital Tecnologia
# Gestão Industrial Eficiência
# Desenvolvimento Web Backend
# Gestão Liderança Comunicação
# Marketing Digital Automacao
# Gestão Processos Análise
# Análise Dados
# Análise Dados Otimização
# Gestão e Organização
# Desenvolvimento Web Fullstack
# Gestão Qualidade Liderança
# Gerenciamento Liderança Eficiência
# Gestão de Conhecimento
# Análise Contabilidade Legislação
# Banco Dados Liderança
# Comunicação Colaboração Excelência
# Comunicação Empática Adaptável
# Desenvolvedor Full Stack
# Atendimento Foco Resultados
# Gestão Eficiência Excelência
# TI Marketing Digital
# Gestão Tecnologia Design
# Desenvolvimento Web Frontend
# Gestão Equipe Comunicação
# Análise Inovação Taxonomia
# Comunicação Liderança Adaptabilidade
# Fiscal Contabilidade Gestão
# Gerenciamento Taxonomia Tecnologia
# Gestão Taxonomia Inova
# Análise Social Ética
# Análise Desenvolvimento Web
# Análise Estratégica Foco
# Análise Tecnologia Execução
# Gestão Conteúdo Criativo
# Liderança Agro Técnico
# Análise Dados Comunicação
# Análise Estratégica Efetiva
# Desenvolvimento Agile Scrum
# Análise Dados Linguagem
# Inteligência Artificial Segurança
# Gestão Projetos Tecnologia
# Trabalho Equipe Colaborativa
# Gestão Análise Projetos
# Gestão Saúde Liderança
# Desenvolvimento Cloud Analytics
# Análise Línguística Avançada
# Ética Liderança Suporte
# Gestão Projetos Excel
# Taxonomia Hierarquica
# Marketing Digital Tecnologia
# Gestão Projetos Arquitetura
# Treinamento Comunicação Dinamismo
# Análise Dados
# Comunicação Linguagem Domínio
# Análise Liderança Colaboração
# Vendas Compras Comunicação
# Processamento Dados Avançado
# Negociação Estratégica Efetiva
# Gestão Organização Liderança
# Gestão Financeira Corporativa
# Técnico Lider Gestor
# Gestão Tecnologia Comunicação
# Análise Cliente Focado
# Suporte Técnico Liderança
# Análise Estratégica Organizacional
# Desenvolvimento Banco Dados
# Comunicação Empatia Produtividade
# Desenvolvimento Software Cloud
# Análise Laboratório Clínica
# Análise Dados Estatística
# Classificação Grupo Profissional
# Análise Dados Office
# Comunicação Eficaz Influência
# Trabalho Em Equipe
# Gestão Resultados Focado
# Análise Dados Cloud
# Desenvolvimento Banco Dados
# Suporte Clientes Comunicação
# Análise Categoria
# Análise Estratégica Gerenciamento
# Gestão Processos Eficiência
# Gestão Comunicação Organização
# Gestão Comunicação Resultados
# Habilidades Sociais
# Gestão Estratégica Efetiva
# Equipe Foco Persistência
# Gestão Saúde Tecnologia
# Trabalho Em Equipe
# Gestão Cloud Análise
# Suporte Técnico Computação
# Gerenciamento Tecnologia Liderança
# Gestão de Projetos
# Data Analysis Expert
# Criacao Conteudo Visual
# Comunicação Interpessoal
# Comunicação Eficaz Proativa
# Direção Veículo Segurança
# Gestão Liderança Financeira
# Equipe Colaborativa Escolar
# Gestão Cliente SAP
# Análise Dados Liderança
# Análise Dados Classificação
# Análise Dados Corporativos
# Gestão Comunicação Aprimoramento
# Gestão de Equipes
# Análise Cultura Linguagem
# Desenvolvimento Banco Dados
# Gestão Liderança Criatividade
# Gestão Comunicação Inovação
# Trabalho Equipe Avançada
# Desenvolvimento Análise Lider
# Desenvolvimento Web Integrado
# Análise Lógica
# Análise Língua Humana
# Gestão Logística
# Gestão de Conhecimento
# Gerenciamento Projetos Comunicação
# Eficiência Estratégica Resultados
# Equipe Comunicação Criatividade
# Análise Dados Automatização
# Desenvolvimento Aplicacoes Multiplataforma
# Análise Dados Digital
# Análise Dados Saúde
# Análise Dados Cloud
# Análise Grupo Eficiente
# Suporte Técnico Personalizado
# Negociação Estratégica
# Análise Dados Melhorias
# Segurança Comunicação Eficaz
# Classificação Hierárquica
# Comunicação Efetiva Clarity
# Análise Dados Estratégia
# Solucionar Problemas Criativos
# Análise Dados Marketing
# Gestão Operações ERP
# Gestão Comunicação Negociação
# Gestão de Processos
# Análise de Dados
# Desenvolvimento Office VBA
# Análise Desenvolvimento Software
# Gestão de Categorias
# Gestão Vendas BIM
# Taxonomia Classificação Categorização
# Análise Vendas Online
# Gestão Emocional Equilibrada
# Clusterização Nivel 1 Concluída

# %%
# ---- GERAÇÃO DOS CLUSTERS NIVEL 2 (ABRANGENTE) ----

from sklearn.cluster import AgglomerativeClustering

# Calcule centroides e nomes dos clusters_n1 (com verificação)
centroides_n1 = []
nomes_n1 = []
clusters_n1_validos = []
for c in sorted(df_final['cluster_n1'].unique()):
    if c == -1:
        continue
    pontos = df_final[df_final['cluster_n1'] == c]
    if len(pontos) == 0:
        continue
    centroides_n1.append([pontos['x'].mean(), pontos['y'].mean()])
    nomes_n1.append(pontos['nome_n1'].iloc[0])
    clusters_n1_validos.append(c)
centroides_n1 = np.array(centroides_n1)

# Agglomerative clustering para o nível 2
n_clusters_nivel2 = 30  # ajuste conforme necessário
cluster_model2 = AgglomerativeClustering(n_clusters=n_clusters_nivel2, linkage='ward')
labels_nivel2 = cluster_model2.fit_predict(centroides_n1)

# Nomeação dos superclusters do nível 2
nomes_nivel2 = {}
for super_c in sorted(np.unique(labels_nivel2)):
    clusters_filhos = [i for i, l in enumerate(labels_nivel2) if l == super_c]
    nomes_filhos = [nomes_n1[i] for i in clusters_filhos]
    nome_super = nomear_cluster(nomes_filhos, nivel=2)
    nomes_nivel2[super_c] = nome_super

# Mapeando cluster_n1 para o supercluster_n2
cluster_n1_to_n2 = {c: labels_nivel2[i] for i, c in enumerate(clusters_n1_validos)}
df_final['cluster_n2'] = df_final['cluster_n1'].map(cluster_n1_to_n2)
df_final.loc[df_final['cluster_n1'] == -1, 'cluster_n2'] = -1

df_final['nome_n2'] = df_final['cluster_n2'].map(nomes_nivel2)
df_final.loc[df_final['cluster_n2'] == -1, 'nome_n2'] = "Ruído"

print("Clusterização Nivel 2 Concluída")
# Out:
# Gestão Corporativa
# Gestão Organizacional
# Desenvolvimento Tecnologia
# Análise Liderança
# Gestão Comunicação
# Tecnologia Informação
# Desenvolvimento Tecnologia
# Gestão Financeira
# Desenvolvimento Tecnologia
# Ciência Dados
# Gestão Pessoas
# Desenvolvimento Tecnologia
# Gestão Tecnologia
# Gestão Empresarial
# Habilidades Sociais
# Análise Dados
# Gestão Corporativa
# Comunicação Eficaz
# Gestão Empresarial
# Trabalho Equipe
# Comunicação Liderança
# Gestão Industrial
# Ciência Dados
# Marketing Digital
# Análise Tecnológica
# Gestão Taxonomia
# Categoria Gestão
# Segurança Veículo
# Gestão Cultural
# Desenvolvimento Tecnológico
# Clusterização Nivel 2 Concluída

# %%
### ---- GERAÇÃO FINAL DO JSON PARA VISUALIZACAO VIA WEB JAVASCRIPT ---- ###

import numpy as np
import pandas as pd
import torch
import umap
import hdbscan
import joblib
import json
from transformers import AutoTokenizer, AutoModel
from groq import Groq

# Junção
df_json = df_final.to_dict(orient="records")
with open("/kaggle/working/visualizacao1_clusters.json", "w", encoding="utf-8") as f:
    json.dump(df_json, f, ensure_ascii=False, indent=2)

print("Pipeline com 4 níveis concluído. Arquivo JSON pronto para visualização web.")
# Out:
# Pipeline com 4 níveis concluído. Arquivo JSON pronto para visualização web.

# %%
### ---- FUNCAO PARA NOMEAÇÃO DOS CLUSTERS (3 NIVEIS) ---- ###

### ---- llama3-8b-8192 / gemma2-9b-it / llama3-8b-8192 ---- ###
# !pip install groq
import numpy as np
import pandas as pd
import torch
import umap
import hdbscan
import joblib
import json
from transformers import AutoTokenizer, AutoModel
from groq import Groq
from kaggle_secrets import UserSecretsClient

user_secrets = UserSecretsClient()
secret_value_0 = user_secrets.get_secret("client")


client = Groq(api_key=secret_value_0)

def nomear_cluster(skills_cluster, nivel):
    niveis_info = {
        0: {"palavras": 4, "exemplo": "Técnicas Avançadas Processamento Linguagem"},
        1: {"palavras": 3, "exemplo": "Desenvolvimento Web Frontend"},
        2: {"palavras": 2, "exemplo": "Engenharia Software"}
    }
    info = niveis_info[nivel]
    limite = info["palavras"]
    exemplo = info["exemplo"]

    msg = ", ".join(skills_cluster)

    user_msg = (
        f"Você apenas tem direito de falar {limite} palavras (sem uso de virgulas, numeros, pontos finais, outros pontos"
        f"asteriscos) resuma essas skills ({msg}) e retorne algo semelhante a isso: {exemplo}."
    )

    completion = client.chat.completions.create(
        model="llama3-70b-8192",
        messages=[
            {"role": "system", "content": f"Você é um profissional que irá me ajudar a classificar grupos"},
            {"role": "user", "content": user_msg}
        ],
        temperature=0.6,
        max_tokens=12,
        top_p=1,
        stream=False,
    )

    try:
        resposta = completion.choices[0].message.content.strip()
        print(resposta)
        # Remove frases comuns caso escapem
        for padrao in [
            "Aqui está", "Aqui estão", "Claro", "Nomes para grupos", "Nomes para Grupos",
            "Nomes curtos", "Exemplo", ":", "#", "-", "Habilidades"
        ]:
            if resposta.lower().startswith(padrao.lower()):
                resposta = resposta[len(padrao):].strip()
        return resposta
    except Exception as e:
        print(f"Erro ao processar resposta: {e}")
        return "Unknown"
# Out:
# Collecting groq
#   Downloading groq-0.28.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from groq) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from groq) (2.11.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.11/dist-packages (from groq) (4.13.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->groq) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->groq) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->groq) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq) (0.4.0)
# Downloading groq-0.28.0-py3-none-any.whl (130 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 4.3 MB/s eta 0:00:00
# Installing collected packages: groq
# Successfully installed groq-0.28.0
# 2025-06-23 17:12:01.025004: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750698721.207588      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750698721.263732      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
import plotly.graph_objects as go

def gerar_hover_text(linha):
    return f"""
    <b>{linha['skill']}</b><br>
    Nível 0: {linha['nome_n0']} (ID: {linha['cluster_n0']})<br>
    """

df_final["hover_text"] = df_final.apply(gerar_hover_text, axis=1)

text=df_final["hover_text"],
hoverinfo="text",

fig = go.Figure()

fig.add_trace(go.Scattergl(
    x=df_final["x"],
    y=df_final["y"],
    mode="markers",
    marker=dict(
        color=df_final["cluster_n3"],  # cor por cluster mais específico
        colorscale="Viridis",
        size=6,
        opacity=0.8,
        showscale=True,
        colorbar=dict(title="Cluster Nível 3")
    ),
    text=df_final["hover_text"],
    hoverinfo="text",
    name="Skills"
))

fig.update_layout(
    title="📌 Mapa Interativo de Skills com Hierarquia Completa",
    xaxis=dict(showgrid=True, visible=True),
    yaxis=dict(showgrid=True, visible=True),
    height=750
)

fig.show()
